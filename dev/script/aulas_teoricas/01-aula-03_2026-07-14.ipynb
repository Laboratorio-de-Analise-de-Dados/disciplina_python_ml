# %%
import os
try:
    os.chdir("aulas_teoricas")
except FileNotFoundError:
    pass

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from joblib import dump, load
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import adjusted_mutual_info_score

from src.line_equation import Line_equation
from src.functions import Functions

# %%
def func_dados(valor) -> float:
    valor_final = 5 + valor*2
    return valor_final

# %%
n = 200
b = np.random.randint(1, 20, n)
b[:10]
# Out:
# array([15,  3, 16, 18, 17, 19, 17,  9,  6, 13])

# %%
a = np.apply_along_axis(func_dados, 0, b)
a[:10]
# Out:
# array([35, 11, 37, 41, 39, 43, 39, 23, 17, 31])

# %%
df = pd.DataFrame(
    data={
        'x': a,
        'y': b
    }
).round(0)
df.head()
# Out:
#     x   y
# 0  35  15
# 1  11   3
# 2  37  16
# 3  41  18
# 4  39  17

# %%
def func_dados_erro(valor: int) -> float:
    erro = np.random.normal(0, 2, 1)
    valor_final = valor + erro[0]
    return valor_final

# %%
df['x_noise'] = df['x'].apply(func=func_dados_erro)
df['y_noise'] = df['y'].apply(func=func_dados_erro)
df.head()
# Out:
#     x   y    x_noise    y_noise
# 0  35  15  36.551838  17.509743
# 1  11   3  13.438995   2.798910
# 2  37  16  38.253656  14.998800
# 3  41  18  40.211238  18.166991
# 4  39  17  39.348092  21.940497

# %%
def novo_valor(valor: int, correct: float, q1y: float, q3y: float) -> float:
    if valor <= q1y:
        return valor + correct
    if valor >= q3y:
        return valor + correct
    return valor

# %%
q1y = df.y_noise.quantile(.25)
q3y = df.y_noise.quantile(.75)

df['y_noise_new'] = df['y_noise'].apply(func=novo_valor, args=(5, q1y, q3y))
df.head()
# Out:
#     x   y    x_noise    y_noise  y_noise_new
# 0  35  15  36.551838  17.509743    22.509743
# 1  11   3  13.438995   2.798910     7.798910
# 2  37  16  38.253656  14.998800    14.998800
# 3  41  18  40.211238  18.166991    23.166991
# 4  39  17  39.348092  21.940497    26.940497

# %%
minx = df.x_noise.min()
q1x = df.x_noise.quantile(.25)
q3x = df.x_noise.quantile(.75)
maxx = df.x_noise.max()

miny = df.y_noise_new.min()
q1y = df.y_noise_new.quantile(.25)
q3y = df.y_noise_new.quantile(.75)
maxy = df.y_noise_new.max()

noise = pd.DataFrame({
    'x':[minx, q1x, q3x, maxx],
    'y':[miny, q1y, q3y, maxy],
})
noise
# Out:
#            x          y
# 0   4.780596   2.295807
# 1  16.342446   8.010732
# 2  36.712816  16.717576
# 3  45.875566  27.304611

# %%
lista_valores = list()

[lista_valores.append(x) for x in np.random.randint(minx, q1x, 50)]
[lista_valores.append(x) for x in np.random.randint(q1x, q3x, 100)]
[lista_valores.append(x) for x in np.random.randint(q3x, maxx, 50)]

df["x_noise_mean"] = np.array(lista_valores)

lista_valores = list()

[lista_valores.append(y) for y in np.random.randint(miny, q1y, 50)]
[lista_valores.append(y) for y in np.random.randint(q1y, q3y, 100)]
[lista_valores.append(y) for y in np.random.randint(q3y, maxy, 50)]

df["y_noise_mean"] = np.array(lista_valores)

df.head()
# Out:
#     x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean
# 0  35  15  36.551838  17.509743    22.509743             4             6
# 1  11   3  13.438995   2.798910     7.798910            15             5
# 2  37  16  38.253656  14.998800    14.998800            10             4
# 3  41  18  40.211238  18.166991    23.166991             8             2
# 4  39  17  39.348092  21.940497    26.940497             9             2

# %%
df_1 = df.sample(frac=.5)
df_2 = df.sample(frac=.5)

# %%
df_1['class'] = True
df_1.loc[df_1['x_noise'].sample(frac=.75).index, 'class'] = False
df_1['class'].value_counts()
# Out:
# False    75
# True     25
# Name: class, dtype: int64

# %%
df_1['style'] = "o"
df_1.loc[df_1[df_1['class']].index, 'style'] = '+'
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 92   25  10  27.421599  10.228176    10.228176            30            10
# 46   11   3  12.975102   2.881177     7.881177            14             4
# 89   27  11  27.341223   7.332673     7.332673            17            14
# 111  35  15  35.427471  11.617974    11.617974            29             8
# 65    9   2   8.888661   3.052594     8.052594            16            12
#
#      class style
# 92   False     o
# 46    True     +
# 89   False     o
# 111  False     o
# 65   False     o

# %%
df_1['style'].value_counts()
# Out:
# o    75
# +    25
# Name: style, dtype: int64

# %%
df_1['style_2'] = "o"
df_1.loc[df_1[df_1['y_noise_new'] > 17].index, 'style_2'] = '+'
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 92   25  10  27.421599  10.228176    10.228176            30            10
# 46   11   3  12.975102   2.881177     7.881177            14             4
# 89   27  11  27.341223   7.332673     7.332673            17            14
# 111  35  15  35.427471  11.617974    11.617974            29             8
# 65    9   2   8.888661   3.052594     8.052594            16            12
#
#      class style style_2
# 92   False     o       o
# 46    True     +       o
# 89   False     o       o
# 111  False     o       o
# 65   False     o       o

# %%
# dump(df_1, './data/01_aula_df_1')
# dump(df_2, './data/01_aula_df_2')
# dump(df, './data/01_aula_df')
# Out:
# ['./data/01_aula_df']

# %%
df = load('./data/01_aula_df')
df_1 = load('./data/01_aula_df_1')
df_2 = load('./data/01_aula_df_2')

# %%
obsr = "Variável 1"
pred = "Variável 2"
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    data=df_1
)
sns.lineplot(
    x='x',
    y='y',
    data=df_1,
    c='r',
)
sns.lineplot(
    x='x_noise_mean',
    y='y_noise_mean',
    data=df_1,
    c='g',
)
sns.lineplot(
    x='x_noise',
    y='y_noise_new',
    data=df_1,
    c='y',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.show()

# %%
print(f"RMSE red: {mean_squared_error(df['x'], df['y'])}")
print(f"RMSE gree: {mean_squared_error(df['x_noise_mean'], df['y_noise_mean'])}")
print(f"RMSE yellow: {mean_squared_error(df['x_noise'], df['x_noise'])}")
# Out:
# RMSE red: 270.505
# RMSE gree: 225.485
# RMSE yellow: 0.0

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    data=df_1
)
sns.lineplot(
    x='x',
    y='y',
    data=df_2,
    c='r',
)
sns.lineplot(
    x='x_noise',
    y='y_noise_new',
    data=df_2,
    c='y',
)
sns.lineplot(
    x='x_noise_mean',
    y='y_noise_mean',
    data=df_2,
    c='g',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.show()

# %%
print(f"RMSE red: {mean_squared_error(df_1['x'], df_2['y'])}")
print(f"RMSE gree: {mean_squared_error(df_1['x_noise_mean'], df_2['y_noise_mean'])}")
print(f"RMSE yellow: {mean_squared_error(df_1['x_noise'], df_2['x_noise'])}")
# Out:
# RMSE red: 422.53
# RMSE gree: 355.02
# RMSE yellow: 319.7892636929653

# %% [markdown]
# ---

# %%
palette = {False:'blue', True:'magenta'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='class',
    style='style',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
def calcular_valor_por_dia(dia: int, valor_inicial: float) -> float:
    """Calcula o valor para um dia específico seguindo a regra:
    - Dias 1 a 4: valor original
    - Dias 5 a 8: incremento de 10% do valor inicial
    - Repete a cada ciclo de 8 dias.
    """
    if dia < 1:
        raise ValueError("O dia deve ser maior ou igual a 1.")
        
    # O operador % (resto da divisão) nos ajuda a mapear 
    # qualquer dia para sua posição equivalente dentro do ciclo de 8 dias (0 a 7)
    posicao_no_ciclo = (dia - 1) % 8
    
    if posicao_no_ciclo < 4:
        return valor_inicial
    else:
        return valor_inicial * 1.10

# %%
calcular_valor_por_dia(1, 100)
# Out:
# 100

# %%
palette = {'o':'black', '+':'black'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
palette = {'o':'blue', '+':'magenta'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [0, 50], # x
    [10, 19], # y
    c='orange',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [30, 30], # x
    [0, 30], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [30, 30], # x
    [0, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [30, 30], # x
    [18, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    28, 17, '*g', markersize=25
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    28, 17, '*', c=palette['+'], markersize=25
)
plt.plot(
    [0, 50], # x
    [10, 19], # y
    c='orange',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    28, 17, '*', c=palette['o'], markersize=25
)
plt.plot(
    [30, 30], # x
    [18, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %% [markdown]
# ---

# %%
n = 50
x = np.random.randint(5, 45, n)
y = np.random.randint(5, 30, n)
df_nova = pd.DataFrame({'x':x,'y':y})
df_nova.head()
# Out:
#     x   y
# 0  29  13
# 1  29  11
# 2   6  23
# 3  43  23
# 4  31   8

# %%
palette = {'x':'blue', 'y':'magenta'}
df_nova['class'] = palette['x']
df_nova.loc[df_nova[df_nova['y'] >= 15].index, 'class'] = palette['y']
df_nova.head()
# Out:
#     x   y    class
# 0  29  13     blue
# 1  29  11     blue
# 2   6  23  magenta
# 3  43  23  magenta
# 4  31   8     blue

# %%
# dump(df_nova, './data/01_aula_df_nova')
df_nova = load('./data/01_aula_df_nova')

# %%
palette = {'magenta': 'magenta', 'blue': 'blue'}
sns.scatterplot(
    x='x',
    y='y',
    hue='class',
    palette=palette,
    legend=False,
    s=100,
    data=df_nova
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
display(len(df_nova[df_nova['class'] == "blue"]))
display(len(df_nova[df_nova['class'] == "blue"])/50*100)
display(len(df_nova[df_nova['class'] != "blue"]))
display(len(df_nova[df_nova['class'] != "blue"])/50*100)
# Out:
# 21
# 42.0
# 29
# 57.99999999999999

# %%
sns.scatterplot(
    x='x',
    y='y',
    hue='class',
    palette=palette,
    legend=False,
    s=100,
    data=df_nova
)
plt.plot(
    [30, 30], # x
    [18, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x',
    y='y',
    hue='class',
    palette=palette,
    legend=False,
    s=100,
    data=df_nova
)
plt.plot(
    [0, 50], # x
    [10, 19], # y
    c='orange',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %% [markdown]
# ---

# %%
x = np.random.randint(543, 592, n)
x
# Out:
# array([549, 578, 581, 571, 591, 566, 551, 589, 544, 570, 555, 553, 585,
#        574, 586, 543, 583, 556, 546, 553, 563, 582, 568, 565, 557, 561,
#        565, 572, 585, 566, 560, 585, 558, 553, 556, 588, 579, 546, 587,
#        579, 570, 579, 543, 574, 559, 551, 560, 549, 556, 584])

# %%
np.mean(x)
# Out:
# 566.48

# %%
np.median(x)
# Out:
# 565.5

# %%
np.std(x)
# Out:
# 14.227072783956649

# %% [markdown]
# ---

# %%
dados = df_1.sample(50).copy()
# dump(dados, "./data/01_aula_dados")
dados = load("./data/01_aula_dados")
dados.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 50   31  13  31.210753  12.337848    12.337848            17            15
# 42   25  10  26.625263  11.133190    11.133190             9             5
# 171  13   4  10.498330   5.430175    10.430175            42            16
# 17   33  14  34.565248  11.379946    11.379946            15             3
# 163  15   5  18.423896   6.248151    11.248151            37            22
#
#      class style style_2
# 50   False     o       o
# 42   False     o       o
# 171  False     o       o
# 17    True     +       o
# 163  False     o       o

# %%
palette = {'o':'black', '+':'black'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
curva = Line_equation(
    dados=dados.loc[:, ['x_noise', 'y_noise_new']],
    coluna_x='x_noise',
    coluna_y='y_noise_new',
)
curva.equacao_da_reta_calculo()
# Out:
# 25.01274246669294

# %%
dados.loc[:, ['x_noise', 'y_noise_new']].max()
# Out:
# x_noise        45.401363
# y_noise_new    25.012742
# dtype: float64

# %%
dados.loc[:, ['x_noise', 'y_noise_new']].min()
# Out:
# x_noise        7.096160
# y_noise_new    4.340706
# dtype: float64

# %%
curva.equacao_da_reta_calculo(new_y=dados.loc[:, ['x_noise', 'y_noise_new']].max()[0])
# Out:
# 25.01274246669294

# %%
curva.equacao_da_reta_calculo(new_y=dados.loc[:, ['x_noise', 'y_noise_new']].min()[0])
# Out:
# 4.340706297487653

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.equacao_da_reta_calculo, args=[12,])
normalizador = 37
dados['y_noise_new_cal'] = dados['y_noise_new']*normalizador
dados.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 50   31  13  31.210753  12.337848    12.337848            17            15
# 42   25  10  26.625263  11.133190    11.133190             9             5
# 171  13   4  10.498330   5.430175    10.430175            42            16
# 17   33  14  34.565248  11.379946    11.379946            15             3
# 163  15   5  18.423896   6.248151    11.248151            37            22
#
#      class style style_2  y_noise_calculo  y_noise_new_cal
# 50   False     o       o        27.199224       456.500358
# 42   False     o       o        24.229661       411.928023
# 171  False     o       o        13.785862       385.916475
# 17    True     +       o        29.371594       421.058007
# 163  False     o       o        18.918457       416.181574

# %%
obsr = 'Gramas'
pred = 'Calorias'
palette = {'o':'black', '+':'black'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [566, 18,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [100, 18,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [300, 10,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [800, -10,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [566, 0,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
rmse = mean_squared_error(dados['y_noise_calculo'],dados['y_noise_new_cal'])
plt.title(f"RMSE: {rmse:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [300, 10,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
rmse = mean_squared_error(dados['y_noise_calculo'],dados['y_noise_new_cal'])
plt.title(f"RMSE: {rmse:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [566, 0,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
sst =np.sum((dados['y_noise_new_cal'] - dados['y_noise_calculo'])**2)
plt.title(f"SQT: {sst:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [50, 16,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
rmse = mean_squared_error(dados['y_noise_calculo'],dados['y_noise_new_cal'])
plt.title(f"RMSE: {rmse:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
ssr = np.sum((dados['y_noise_new_cal'] - dados['y_noise_calculo'])**2)
plt.title(f"SQR: {ssr:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
r2 = 1-(ssr/sst)
r2
# Out:
# 0.7254689561257941

# %%
tam = len(dados['y_noise_new_cal'])
r2a = 1 - (tam/(tam-1))*(1-r2)
r2a
# Out:
# 0.7198662817610144

# %%
y_obs = dados['y_noise_new_cal']
y_pred = dados['y_noise_calculo']
r2_score(y_obs, y_pred)
# Out:
# 0.6687057250989165

# %%
mae = np.sum(((y_obs - y_pred)**2)**0.5)/tam
mae
# Out:
# 105.53059627579107

# %%
mean_absolute_error(y_obs, y_pred)
# Out:
# 105.53059627579107

# %%
mse = np.sum((y_obs - y_pred)**2)/tam
mse
# Out:
# 14441.936393214384

# %%
mean_squared_error(y_obs, y_pred)
# Out:
# 14441.936393214384

# %%
rmae = mae**0.5
rmae
# Out:
# 10.272808587518366

# %%
root_mean_squared_error(y_obs, y_pred)
# Out:
# 120.17460793867556

# %%
mape = np.sum((((y_obs - y_pred)**2)**0.5)/y_obs)/tam
mape
# Out:
# 0.23873286041624758

# %%
mean_absolute_percentage_error(y_obs, y_pred)
# Out:
# 0.23873286041624758

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)    
plt.plot(
    18, 572, '*', c='g', markersize=25
)
plt.arrow(
    18,
    340,
    0,
    196,
    head_width=1,
    head_length=50,
    length_includes_head=True,
    color='g',
)
rmse = mean_squared_error(dados['y_noise_calculo'],dados['y_noise_new_cal'])
plt.title(f"RMSE: {rmse:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %% [markdown]
# ---

# %%
dados[['x_noise', 'y_noise_new_cal']].head()
# Out:
#        x_noise  y_noise_new_cal
# 50   31.210753       456.500358
# 42   26.625263       411.928023
# 171  10.498330       385.916475
# 17   34.565248       421.058007
# 163  18.423896       416.181574

# %%
obsr = 'Gramas'
pred = 'Calorias'
palette = {'o':'g', '+':'r'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
def __ponto_estrela(df_sample: pd.DataFrame, x: str, y: str) -> list:
    index_superior = (
        df_sample[y][df_sample[y] >= 600]
        .sample(1)
        .index[0]
    )
    retorno = [df_sample.loc[index_superior, x]]
    retorno.append(df_sample.loc[index_superior, y])

    index_inferior = (
        df_sample[y][df_sample[y] < 600]
        .sample(1)
        .index[0]
    )
    retorno.append(df_sample.loc[index_inferior, x])
    retorno.append(df_sample.loc[index_inferior, y])
    return retorno

def seta_estrela(
        df_sample: pd.DataFrame,
        x: str,
        y: str,
        color: str = 'g',
        seta: bool = False,
        n_setas: int = 5) -> None:
    palette = {'o':'g', '+':'r'}
    sns.scatterplot(
        x=x,
        y=y,
        hue='style_2',
        legend=False,
        s=100,
        palette=palette,
        data=df_sample,
    )
    x_estrela, y_estrela, _, _ = __ponto_estrela(df_sample, x, y)
    plt.plot(
        x_estrela,
        y_estrela,
        '*' + color,
        markersize=15
    )
    if seta:
        for _ in range(n_setas):
            index = df_sample[x].sample(1).index[0]
            dx = df_sample[x][index] - x_estrela
            dy = df_sample[y][index] - y_estrela
            plt.arrow(
                x_estrela,
                y_estrela, 
                dx,
                dy,
                head_width=1,
                head_length=1,
                length_includes_head=True,
                color=color,
            )
    _, _, x_estrela, y_estrela = __ponto_estrela(df_sample, x, y)
    plt.plot(
        x_estrela,
        y_estrela,
        '*' + color,
        markersize=15
    )
    if seta:
        for _ in range(n_setas):
            index = df_sample[x].sample(1).index[0]
            dx = df_sample[x][index] - x_estrela
            dy = df_sample[y][index] - y_estrela
            plt.arrow(
                x_estrela,
                y_estrela, 
                dx,
                dy,
                head_width=1,
                head_length=1,
                length_includes_head=True,
                color=color,
            )
    return None

# %%
grafico = {
    "df_sample": dados,
    'x': 'x_noise',
    'y': 'y_noise_new_cal',
    'seta': True,
}
seta_estrela(**grafico)
grafico = {
    "df_sample": dados,
    'x': 'x_noise',
    'y': 'y_noise_new_cal',
    'color': 'r',
    'seta': True,
}
obsr = 'Gramas'
pred = 'Calorias'
seta_estrela(**grafico)
plt.title('Scatter Plot de X/Y')
plt.xlabel(obsr)
plt.ylabel(pred)
plt.show()

# %%
palette = {'o':0, '+':1}
silhouette_score(
    dados['x_noise'].to_frame(),
    dados['style_2'].replace(palette).to_frame()
)
# Out:
# /usr/local/lib/python3.10/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.34489127694476696

# %%
calinski_harabasz_score(
    dados['x_noise'].to_frame(),
    dados['style_2'].replace(palette).to_frame()
)
# Out:
# /usr/local/lib/python3.10/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 36.651336145999636

# %%
davies_bouldin_score(
    dados[['x_noise', 'y_noise_new_cal']],
    dados['style_2'].replace(palette).to_frame()
)
# Out:
# /usr/local/lib/python3.10/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.2625554867204775

# %%
dados.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 50   31  13  31.210753  12.337848    12.337848            17            15
# 42   25  10  26.625263  11.133190    11.133190             9             5
# 171  13   4  10.498330   5.430175    10.430175            42            16
# 17   33  14  34.565248  11.379946    11.379946            15             3
# 163  15   5  18.423896   6.248151    11.248151            37            22
#
#      class style style_2  y_noise_calculo  y_noise_new_cal
# 50   False     o       o       549.372053       456.500358
# 42   False     o       o       476.004216       411.928023
# 171  False     o       o       217.973278       385.916475
# 17    True     +       o       603.043970       421.058007
# 163  False     o       o       344.782342       416.181574

# %%
adjusted_rand_score(
    dados['x'],
    dados['x_noise_mean'],
)
# Out:
# 0.018116676806597714

# %%
adjusted_mutual_info_score(
    dados['x'],
    dados['x_noise_mean'],
)
# Out:
# 0.02626681271245625

# %% [markdown]
# ---

# %%
data = [
[2025,16537],
[2024,5434],
[2023,38871],
[2022,39224],
[2021,31559],
[2020,2278],
[2019,16472],
[2018,11267],
[2017,8257],
[2016,6832],
[2015,6803],
[2014,6908],
[2013,6832],
[2012,5574],
[2011,5314],
[2010,4491],
[2009,4642],
[2008,4906],
[2007,4467],
[2006,4065],
[2005,3639],
[2004,2762],
[2003,1802],
[2002,1462],
[2001,1343],
[2000,1248],
[1999,106],
[1998,1025],
[1997,982],
[1996,862],
[1995,905],
[1994,729],
[1993,61],
[1992,438],
[1991,456],
[1990,372],
[1989,295],
[1988,219],
[1987,198],
[1986,165],
[1985,65],
[1984,3],
[1983,23],
[1982,13],
[1981,11],
[1980,12],
[1979,4],
[1978,3],
[1977,5],
[1976,7],
[1975,5],
[1974,7],
[1973,6],
[1972,5],
[1971,3],
[1970,2],
[1969,1],
[1968,5],
[1967,3],
[1966,2],
[1965,4],
[1964,5],
[1963,5],
[1962,6],
[1961,3],
[1960,1],
[1958,1],
[1956,1],
[1954,1],
[1953,1],
[1952,1],
[1951,1],
]
dados_pubmed = pd.DataFrame(data)
dados_pubmed.rename(columns={0: 'Year', 1: 'Works'}, inplace=True)
dados_pubmed.head()
# Out:
#    Year  Works
# 0  2025  16537
# 1  2024   5434
# 2  2023  38871
# 3  2022  39224
# 4  2021  31559

# %%
plt.figure(figsize=(20,5))
plt.title('Número de Públicações com IA no Pubmed')
sns.barplot(
    x='Year',
    y='Works',
    color='green',
    data=dados_pubmed
)
plt.xticks(rotation=90)
plt.show()

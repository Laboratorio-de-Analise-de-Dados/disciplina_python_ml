# %%
import os
try:
    os.chdir("aulas_teoricas")
except FileNotFoundError:
    pass

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from joblib import dump, load
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

from src.line_equation import Line_equation
from src.functions import Functions

# %%
def func_dados(valor) -> float:
    valor_final = 5 + valor*2
    return valor_final

# %%
n = 200
b = np.random.randint(1, 20, n)
b[:10]
# Out:
# array([ 7, 15,  8,  6, 12,  6,  1,  8, 15, 10])

# %%
a = np.apply_along_axis(func_dados, 0, b)
a[:10]
# Out:
# array([19, 35, 21, 17, 29, 17,  7, 21, 35, 25])

# %%
df = pd.DataFrame(
    data={
        'x': a,
        'y': b
    }
).round(0)
df.head()
# Out:
#     x   y
# 0  19   7
# 1  35  15
# 2  21   8
# 3  17   6
# 4  29  12

# %%
def func_dados_erro(valor: int) -> float:
    erro = np.random.normal(0, 2, 1)
    valor_final = valor + erro[0]
    return valor_final

# %%
df['x_noise'] = df['x'].apply(func=func_dados_erro)
df['y_noise'] = df['y'].apply(func=func_dados_erro)
df.head()
# Out:
#     x   y    x_noise    y_noise
# 0  19   7  17.933498   2.962984
# 1  35  15  32.931656  13.908510
# 2  21   8  21.796246   6.687949
# 3  17   6  17.498136   8.655326
# 4  29  12  30.651426   9.869493

# %%
def novo_valor(valor: int, correct: float, q1y: float, q3y: float) -> float:
    if valor <= q1y:
        return valor + correct
    if valor >= q3y:
        return valor + correct
    return valor

# %%
q1y = df.y_noise.quantile(.25)
q3y = df.y_noise.quantile(.75)

df['y_noise_new'] = df['y_noise'].apply(func=novo_valor, args=(5, q1y, q3y))
df.head()
# Out:
#     x   y    x_noise    y_noise  y_noise_new
# 0  19   7  17.933498   2.962984     7.962984
# 1  35  15  32.931656  13.908510    13.908510
# 2  21   8  21.796246   6.687949     6.687949
# 3  17   6  17.498136   8.655326     8.655326
# 4  29  12  30.651426   9.869493     9.869493

# %%
minx = df.x_noise.min()
q1x = df.x_noise.quantile(.25)
q3x = df.x_noise.quantile(.75)
maxx = df.x_noise.max()

miny = df.y_noise_new.min()
q1y = df.y_noise_new.quantile(.25)
q3y = df.y_noise_new.quantile(.75)
maxy = df.y_noise_new.max()

noise = pd.DataFrame({
    'x':[minx, q1x, q3x, maxx],
    'y':[miny, q1y, q3y, maxy],
})
noise
# Out:
#            x          y
# 0   4.160287   2.981662
# 1  14.872121   7.558135
# 2  34.377760  16.728171
# 3  46.168488  25.484451

# %%
lista_valores = list()

[lista_valores.append(x) for x in np.random.randint(minx, q1x, 50)]
[lista_valores.append(x) for x in np.random.randint(q1x, q3x, 100)]
[lista_valores.append(x) for x in np.random.randint(q3x, maxx, 50)]

df["x_noise_mean"] = np.array(lista_valores)

lista_valores = list()

[lista_valores.append(y) for y in np.random.randint(miny, q1y, 50)]
[lista_valores.append(y) for y in np.random.randint(q1y, q3y, 100)]
[lista_valores.append(y) for y in np.random.randint(q3y, maxy, 50)]

df["y_noise_mean"] = np.array(lista_valores)

df.head()
# Out:
#     x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean
# 0  19   7  17.933498   2.962984     7.962984             9             6
# 1  35  15  32.931656  13.908510    13.908510            13             5
# 2  21   8  21.796246   6.687949     6.687949             4             5
# 3  17   6  17.498136   8.655326     8.655326             4             4
# 4  29  12  30.651426   9.869493     9.869493             8             3

# %%
df_1 = df.sample(frac=.5)
df_2 = df.sample(frac=.5)

# %%
df_1['class'] = True
df_1.loc[df_1['x_noise'].sample(frac=.75).index, 'class'] = False
df_1['class'].value_counts()
# Out:
# False    75
# True     25
# Name: class, dtype: int64

# %%
df_1['style'] = "o"
df_1.loc[df_1[df_1['class']].index, 'style'] = '+'
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 105  21   8  21.497543   8.635228     8.635228            31            14
# 87   35  15  38.204633  12.636329    12.636329            14            11
# 91   11   3  12.923284   8.173737     8.173737            32            13
# 65   11   3  12.004073   1.915587     6.915587            17            15
# 107   7   1   7.847546   0.148392     5.148392            20            13
#
#      class style
# 105   True     +
# 87    True     +
# 91   False     o
# 65   False     o
# 107  False     o

# %%
df_1['style'].value_counts()
# Out:
# o    75
# +    25
# Name: style, dtype: int64

# %%
df_1['style_2'] = "o"
df_1.loc[df_1[df_1['y_noise_new'] > 17].index, 'style_2'] = '+'
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 105  21   8  21.497543   8.635228     8.635228            31            14
# 87   35  15  38.204633  12.636329    12.636329            14            11
# 91   11   3  12.923284   8.173737     8.173737            32            13
# 65   11   3  12.004073   1.915587     6.915587            17            15
# 107   7   1   7.847546   0.148392     5.148392            20            13
#
#      class style style_2
# 105   True     +       o
# 87    True     +       o
# 91   False     o       o
# 65   False     o       o
# 107  False     o       o

# %%
# dump(df_1, './data/00_aula_df_1')
# dump(df_2, './data/00_aula_df_2')
# dump(df, './data/00_aula_df')

# %%
df = load('./data/00_aula_df')
df_1 = load('./data/00_aula_df_1')
df_2 = load('./data/00_aula_df_2')

# %%
obsr = "Variável 1"
pred = "Variável 2"
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    data=df_1
)
sns.lineplot(
    x='x',
    y='y',
    data=df_1,
    c='r',
)
sns.lineplot(
    x='x_noise_mean',
    y='y_noise_mean',
    data=df_1,
    c='g',
)
sns.lineplot(
    x='x_noise',
    y='y_noise_new',
    data=df_1,
    c='y',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.show()

# %%
print(f"RMSE red: {mean_squared_error(df['x'], df['y'])}")
print(f"RMSE gree: {mean_squared_error(df['x_noise_mean'], df['y_noise_mean'])}")
print(f"RMSE yellow: {mean_squared_error(df['x_noise'], df['x_noise'])}")
# Out:
# RMSE red: 265.95
# RMSE gree: 202.595
# RMSE yellow: 0.0

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    data=df_1
)
sns.lineplot(
    x='x',
    y='y',
    data=df_2,
    c='r',
)
sns.lineplot(
    x='x_noise',
    y='y_noise_new',
    data=df_2,
    c='y',
)
sns.lineplot(
    x='x_noise_mean',
    y='y_noise_mean',
    data=df_2,
    c='g',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.show()

# %%
print(f"RMSE red: {mean_squared_error(df_1['x'], df_2['y'])}")
print(f"RMSE gree: {mean_squared_error(df_1['x_noise_mean'], df_2['y_noise_mean'])}")
print(f"RMSE yellow: {mean_squared_error(df_1['x_noise'], df_2['x_noise'])}")
# Out:
# RMSE red: 433.68
# RMSE gree: 309.91
# RMSE yellow: 251.65325563830524

# %% [markdown]
# ---

# %%
palette = {False:'blue', True:'magenta'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='class',
    style='style',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
palette = {'o':'black', '+':'black'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
palette = {'o':'blue', '+':'magenta'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [0, 50], # x
    [10, 19], # y
    c='orange',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [30, 30], # x
    [0, 30], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [30, 30], # x
    [0, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [30, 30], # x
    [18, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    28, 17, '*g', markersize=25
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    28, 17, '*', c=palette['+'], markersize=25
)
plt.plot(
    [0, 50], # x
    [10, 19], # y
    c='orange',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    28, 17, '*', c=palette['o'], markersize=25
)
plt.plot(
    [30, 30], # x
    [18, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %% [markdown]
# ---

# %%
n = 50
x = np.random.randint(5, 45, n)
y = np.random.randint(5, 30, n)
df_nova = pd.DataFrame({'x':x,'y':y})
df_nova.head()
# Out:
#     x   y
# 0  44  14
# 1  16   5
# 2  11  11
# 3  20  11
# 4  38   5

# %%
palette = {'x':'blue', 'y':'magenta'}
df_nova['class'] = palette['x']
df_nova.loc[df_nova[df_nova['y'] >= 15].index, 'class'] = palette['y']
df_nova.head()
# Out:
#     x   y class
# 0  44  14  blue
# 1  16   5  blue
# 2  11  11  blue
# 3  20  11  blue
# 4  38   5  blue

# %%
# dump(df_nova, './data/00_aula_df_nova')
df_nova = load('./data/00_aula_df_nova')

# %%
palette = {'magenta': 'blue', 'blue': 'magenta'}
sns.scatterplot(
    x='x',
    y='y',
    hue='class',
    # style='class',
    palette=palette,
    legend=False,
    s=100,
    data=df_nova
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x',
    y='y',
    hue='class',
    # style='class',
    palette=palette,
    legend=False,
    s=100,
    data=df_nova
)
plt.plot(
    [30, 30], # x
    [18, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x',
    y='y',
    hue='class',
    # style='class',
    palette=palette,
    legend=False,
    s=100,
    data=df_nova
)
plt.plot(
    [0, 50], # x
    [10, 19], # y
    c='orange',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %% [markdown]
# ---

# %%
x = np.random.randint(543, 592, n)
x
# Out:
# array([587, 557, 555, 579, 560, 571, 576, 580, 552, 547, 547, 546, 576,
#        575, 558, 567, 543, 568, 557, 563, 554, 545, 586, 586, 548, 548,
#        546, 583, 548, 575, 546, 585, 565, 559, 552, 566, 570, 585, 573,
#        564, 564, 578, 590, 569, 553, 543, 555, 558, 575, 554])

# %%
np.mean(x)
# Out:
# 563.74

# %%
np.median(x)
# Out:
# 563.5

# %%
np.std(x)
# Out:
# 13.788125325801184

# %% [markdown]
# ---

# %%
dados = df_1.sample(50).copy()
# dump(dados, "./data/00_aula_dados")
dados = load("./data/00_aula_dados")
dados.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 80   43  19  42.084393  17.672094    22.672094            29            13
# 25   33  14  34.263556  18.198012    23.198012            10             5
# 60   29  12  26.910875  13.187302    13.187302            24            14
# 118  39  17  38.860440  15.478574    20.478574            31            13
# 93   11   3  12.397569   2.526547     7.526547            28            12
#
#      class style style_2
# 80    True     +       +
# 25    True     +       +
# 60   False     o       o
# 118  False     o       +
# 93   False     o       o

# %%
palette = {'o':'black', '+':'black'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
curva = Functions(
    dados=dados.loc[:, ['x_noise', 'y_noise_new']],
    coluna_x='x_noise',
    coluna_y='y_noise_new',
)
curva.equacao_da_reta_calculo()
# Out:
# 25.954514747125646

# %%
dados.loc[:, ['x_noise', 'y_noise_new']].max()
# Out:
# x_noise        44.816347
# y_noise_new    25.954515
# dtype: float64

# %%
dados.loc[:, ['x_noise', 'y_noise_new']].min()
# Out:
# x_noise        2.620217
# y_noise_new    5.492658
# dtype: float64

# %%
curva.equacao_da_reta_calculo(new_y=dados.loc[:, ['x_noise', 'y_noise_new']].max()[0])
# Out:
# 25.954514747125646

# %%
curva.equacao_da_reta_calculo(new_y=dados.loc[:, ['x_noise', 'y_noise_new']].min()[0])
# Out:
# 5.492658206396417

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.equacao_da_reta_calculo, args=[12,])
normalizador = 37
dados['y_noise_new_cal'] = dados['y_noise_new']*normalizador
# dados['y_noise_calculo'] = dados['x_noise'].apply(curva.equacao_da_reta_calculo)
dados.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 80   43  19  42.084393  17.672094    22.672094            29            13
# 25   33  14  34.263556  18.198012    23.198012            10             5
# 60   29  12  26.910875  13.187302    13.187302            24            14
# 118  39  17  38.860440  15.478574    20.478574            31            13
# 93   11   3  12.397569   2.526547     7.526547            28            12
#
#      class style style_2  y_noise_calculo  y_noise_new_cal
# 80    True     +       +        34.530335       838.867481
# 25    True     +       +        29.979334       858.326456
# 60   False     o       o        25.700756       487.930164
# 118  False     o       +        32.654293       757.707220
# 93   False     o       o        17.255360       278.482223

# %%
obsr = 'Gramas'
pred = 'Calorias'
palette = {'o':'black', '+':'black'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [600, 0,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
rmse = mean_squared_error(dados['y_noise_calculo'],dados['y_noise_new_cal'])
plt.title(f"RMSE: {rmse:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
obsr = "Observado"
pred = "Predito"

dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
sst =np.sum((dados['y_noise_new_cal'] - dados['y_noise_calculo'])**2)
plt.title(f"SQT: {sst:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [50, 16,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
obsr = "Observado"
pred = "Predito"

dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
ssr =np.sum((dados['y_noise_new_cal'] - dados['y_noise_calculo'])**2)
plt.title(f"SQR: {ssr:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
r2 = 1-(ssr/sst)
r2
# Out:
# 0.7287511081505802

# %%
tam = len(dados['y_noise_new_cal'])
r2a = 1 - (tam/(tam-1))*(1-r2)
r2a
# Out:
# 0.7232154164801838

# %%
y_obs = dados['y_noise_new_cal']
y_pred = dados['y_noise_calculo']
r2_score(y_obs, y_pred)
# Out:
# 0.685126653362382

# %%
mae = np.sum(((y_obs - y_pred)**2)**0.5)/tam
mae
# Out:
# 101.17060066563135

# %%
mean_absolute_error(y_obs, y_pred)
# Out:
# 101.17060066563135

# %%
mse = np.sum((y_obs - y_pred)**2)/tam
mse
# Out:
# 15663.46010844885

# %%
mean_squared_error(y_obs, y_pred)
# Out:
# 15663.46010844885

# %%
rmae = mae**0.5
rmae
# Out:
# 10.058359740317075

# %%
root_mean_squared_error(y_obs, y_pred)
# Out:
# 125.15374588260973

# %%
mape = np.sum((((y_obs - y_pred)**2)**0.5)/y_obs)/tam
mape
# Out:
# 0.21302396847665317

# %%
mean_absolute_percentage_error(y_obs, y_pred)
# Out:
# 0.21302396847665317

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)    
plt.plot(
    18, 566, '*', c='g', markersize=25
)
plt.arrow(
    18,
    340,
    0,
    196,
    head_width=1,
    head_length=50,
    length_includes_head=True,
    color='g',
)
rmse = mean_squared_error(dados['y_noise_calculo'],dados['y_noise_new_cal'])
plt.title(f"RMSE: {rmse:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %% [markdown]
# ---

# %%
data = [
[2025,16537],
[2024,5434],
[2023,38871],
[2022,39224],
[2021,31559],
[2020,2278],
[2019,16472],
[2018,11267],
[2017,8257],
[2016,6832],
[2015,6803],
[2014,6908],
[2013,6832],
[2012,5574],
[2011,5314],
[2010,4491],
[2009,4642],
[2008,4906],
[2007,4467],
[2006,4065],
[2005,3639],
[2004,2762],
[2003,1802],
[2002,1462],
[2001,1343],
[2000,1248],
[1999,106],
[1998,1025],
[1997,982],
[1996,862],
[1995,905],
[1994,729],
[1993,61],
[1992,438],
[1991,456],
[1990,372],
[1989,295],
[1988,219],
[1987,198],
[1986,165],
[1985,65],
[1984,3],
[1983,23],
[1982,13],
[1981,11],
[1980,12],
[1979,4],
[1978,3],
[1977,5],
[1976,7],
[1975,5],
[1974,7],
[1973,6],
[1972,5],
[1971,3],
[1970,2],
[1969,1],
[1968,5],
[1967,3],
[1966,2],
[1965,4],
[1964,5],
[1963,5],
[1962,6],
[1961,3],
[1960,1],
[1958,1],
[1956,1],
[1954,1],
[1953,1],
[1952,1],
[1951,1],
]
dados_pubmed = pd.DataFrame(data)
dados_pubmed.rename(columns={0: 'Year', 1: 'Works'}, inplace=True)
dados_pubmed.head()
# Out:
#    Year  Works
# 0  2025  16537
# 1  2024   5434
# 2  2023  38871
# 3  2022  39224
# 4  2021  31559

# %%
plt.figure(figsize=(20,5))
plt.title('Número de Públicações com IA no Pubmed')
sns.barplot(
    x='Year',
    y='Works',
    color='green',
    data=dados_pubmed
)
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
colunas = {
    0: "Acurácia",
    1: "Precision",
    2: "Recall",
    3: "F1-score",
    4: "KS",
    5: "AUC",
    6: "GINI"
}
dados = {
    "K-means": [0.9667, 0.9524, 1, 0.9756, 0.95, 0.995, 0.99],
    "DBSCAN": [0.9, 0.875, 1, 0.9333, 0.9048, 0.9841, 0.9683],
    "NN-k-means": [0.9667, 1, 0.95, 0.9744, 0.95, 0.995, 0.99],
    "K-NN": [0.9, 0.9412, 0.8889, 0.9143, 0.9167, 0.9838, 0.9676],
    "SVM": [0.9, 0.8889, 0.9412, 0.9143, 0.7873, 0.8937, 0.7873],
    "Dec Tree": [0.8, 0.9231, 0.7059, 0.8, 0.629, 0.8145, 0.629],
    "Random Forests": [0.8, 0.9231, 0.7059, 0.8, 0.629, 0.8145, 0.629],
    "GBM": [0.9667, 0.9444, 1, 0.9714, 0.9231, 0.9615, 0.9231],
    "Naive Bayes": [0.9667, 0.9444, 1, 0.9714, 0.9231, 0.9615, 0.9231],
    "Redes Neurais": [0.8667, 0.8095, 1, 0.8947, 0.6923, 0.8462, 0.6923]
}

# %%
df = pd.DataFrame(dados).T
df.rename(columns=colunas, inplace=True)
df
# Out:
#                 Acurácia  Precision  Recall  F1-score      KS     AUC    GINI
# K-means           0.9667     0.9524  1.0000    0.9756  0.9500  0.9950  0.9900
# DBSCAN            0.9000     0.8750  1.0000    0.9333  0.9048  0.9841  0.9683
# NN-k-means        0.9667     1.0000  0.9500    0.9744  0.9500  0.9950  0.9900
# K-NN              0.9000     0.9412  0.8889    0.9143  0.9167  0.9838  0.9676
# SVM               0.9000     0.8889  0.9412    0.9143  0.7873  0.8937  0.7873
# Dec Tree          0.8000     0.9231  0.7059    0.8000  0.6290  0.8145  0.6290
# Random Forests    0.8000     0.9231  0.7059    0.8000  0.6290  0.8145  0.6290
# GBM               0.9667     0.9444  1.0000    0.9714  0.9231  0.9615  0.9231
# Naive Bayes       0.9667     0.9444  1.0000    0.9714  0.9231  0.9615  0.9231
# Redes Neurais     0.8667     0.8095  1.0000    0.8947  0.6923  0.8462  0.6923

# %%
df.T.plot(
    kind='bar',
    figsize=(15, 3),
    title='Métricas de Classificação',
    xlabel='Modelos',
    ylabel='Valores',
)
plt.xticks(rotation=45)
plt.legend(
    loc='upper left',
    ncols=1,
    bbox_to_anchor=(0, -0.5, 1, 0.2)
)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_33346/832679098.py:14: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
colunas = {
    0: "R Spearman Correlação",
    1: "R p-value Correlação",
    2: "R² Determinação",
    3: "MAE",
    4: "RMSE",
    5: "MAPE"
}
dados = {
    "Linear Simples": [0.86, 0, 0.8, 3.92, 23.53, 0.27],
    "Linear Multipla": [0.88, 0, 0.83, 3.56, 19.69, 0.23],
    "SVM": [0.82, 0, 0.62, 4.5, 45.03, 0.27],
    "Naive Bayes": [0.87, 0, 0.75, 3.26, 28.93, 0.23],
    "Redes Neurais": [0.85, 0, -0.05, 9.32, 126.98, 0.55]
}

# %%
df = pd.DataFrame(dados).T
df.rename(columns=colunas, inplace=True)
df
# Out:
#                  R Spearman Correlação  R p-value Correlação  R² Determinação  \
# Linear Simples                    0.86                   0.0             0.80
# Linear Multipla                   0.88                   0.0             0.83
# SVM                               0.82                   0.0             0.62
# Naive Bayes                       0.87                   0.0             0.75
# Redes Neurais                     0.85                   0.0            -0.05
#
#                   MAE    RMSE  MAPE
# Linear Simples   3.92   23.53  0.27
# Linear Multipla  3.56   19.69  0.23
# SVM              4.50   45.03  0.27
# Naive Bayes      3.26   28.93  0.23
# Redes Neurais    9.32  126.98  0.55

# %%
df.T.plot(
    kind='bar',
    figsize=(15, 3),
    title='Métricas de Classificação',
    xlabel='Modelos',
    ylabel='Valores',
)
plt.xticks(rotation=45)
plt.legend(
    loc='upper left',
    ncols=1,
    bbox_to_anchor=(0, -1, 1, 0.2)
)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_33346/465105231.py:14: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df.iloc[:, 5].T.plot(
    kind='bar',
    figsize=(15, 3),
    title='Métricas de Classificação',
    xlabel='Modelos',
    ylabel='Valores',
)
plt.xticks(rotation=45)
plt.legend(
    loc='upper left',
    ncols=1,
    # bbox_to_anchor=(0, -1, 1, 0.2)
)
plt.tight_layout()
plt.show()

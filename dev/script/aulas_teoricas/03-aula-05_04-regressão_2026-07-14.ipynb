# %% [markdown]
# # Algoritmos

# %% [markdown]
# ## Gerando dados

# %%
import os
try:
    os.chdir("aulas_teoricas")
except FileNotFoundError:
    pass

from joblib import dump, load

import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

# %%
df_10 = load('./data/05_aula_df_10')
df_10.head()
# Out:
#      indep_1  indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  \
# 53        41    24.36            1            0            0            0
# 93         9     8.05            0            1            0            1
# 20        36    19.92            1            0            0            0
# 177       13     7.73            1            0            1            0
# 26        17     6.21            1            0            1            0
#
#      indep_4_max  target  k_means  DBSCAN_1  ...  NN_DBSCAN_1  hierarchy  \
# 53             1       0        0         0  ...            0          0
# 93             0       1        1         1  ...            1          1
# 20             1       0        0         0  ...            0          0
# 177            0       1        1         1  ...            1          1
# 26             0       1        1         1  ...            1          1
#
#      k_NN  log_reg  SVM  dec_tree  random_forest  gbm  nb  NN
# 53      0        0    0         0              0    0   0   1
# 93      1        1    1         1              1    1   1   1
# 20      0        0    0         0              0    0   0   1
# 177     1        1    1         1              1    1   0   1
# 26      1        1    1         1              1    1   0   1
#
# [5 rows x 21 columns]

# %%
df_reg = df_10.iloc[:, [0, 1, 2, 3, 4, 5, 6]].copy()
df_reg['target'] = df_10['indep_1']
df_reg.drop(columns=['indep_1'], inplace=True)
df_reg.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target
# 53       41
# 93        9
# 20       36
# 177      13
# 26       17

# %%
sns.histplot(
    x='target',
    bins=20,
    data=df_reg,
)
plt.title('Target Distribution')
plt.xlabel('target')
plt.ylabel('#')
plt.show()

# %%
sns.scatterplot(
    x='indep_2',
    y='target',
    s=20,
    data=df_reg,
)
plt.title('Variável independete 1 vs Target')
plt.xlabel('Independete')
plt.ylabel('Target')
plt.show()

# %% [markdown]
# ## Regressão Linear Simples

# %%
from src.line_equation import Line_equation
import statsmodels.formula.api as smf
import numpy as np

from scipy.stats import spearmanr
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
def train_test_df(df: pd.DataFrame) -> tuple:
    '''    Função que divide o DataFrame em treino e teste
    '''
    index = df.sample(frac=0.3, random_state=42).index
    df_train = df.loc[[i for i in df.index if i not in index], :]
    df_test = df.loc[index, :]

    print(f"df_train: {df_train.shape}")
    print(f"df_test: {df_test.shape}")

    return df_train, df_test

# %%
def train_test_df_split(df: pd.DataFrame, indep: list, target: str = "target") -> tuple:
    '''
        Função que divide o DataFrame em treino e teste
    '''
    df_train, df_test = train_test_df(df)

    X_train = df_train.loc[:, indep].copy()
    X_test = df_test.loc[:, indep].copy()

    y_train = df_train.loc[:, target].copy()
    y_test = df_test.loc[:, target].copy()

    print(f"X_train: {X_train.shape}")
    print(f"X_test: {X_test.shape}")
    print(f"y_train: {y_train.shape}")
    print(f"y_test: {y_test.shape}")

    return df_train, df_test, X_train, X_test, y_train, y_test

# %%
df_reg.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target
# 53       41
# 93        9
# 20       36
# 177      13
# 26       17

# %%
indep = df_reg.columns[[0, 1, 2, 3, 4, 5]]
df_reg_train, df_reg_test, X_test, X_train, y_test, y_train = train_test_df_split(df=df_reg, indep=indep)
# Out:
# df_train: (70, 7)
# df_test: (30, 7)
# X_train: (70, 6)
# X_test: (30, 6)
# y_train: (70,)
# y_test: (30,)

# %%
modelo = '''
                target ~ 
                indep_2
        '''
reg_simpl = smf.ols(modelo, data=df_reg_train).fit()
reg_simpl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     207.4
# Date:                Thu, 30 Jul 2026   Prob (F-statistic):           2.47e-22
# Time:                        19:08:54   Log-Likelihood:                -218.34
# No. Observations:                  70   AIC:                             440.7
# Df Residuals:                      68   BIC:                             445.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.5752      1.438      3.877      0.000       2.706       8.445
# indep_2        1.4859      0.103     14.400      0.000       1.280       1.692
# ==============================================================================
# Omnibus:                        0.089   Durbin-Watson:                   1.707
# Prob(Omnibus):                  0.956   Jarque-Bera (JB):                0.015
# Skew:                          -0.027   Prob(JB):                        0.993
# Kurtosis:                       2.954   Cond. No.                         30.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_4_copy = df_reg_train.copy()
curva = Line_equation(
    dados=df_4_copy.loc[:, ['indep_2', 'target']],
    coluna_x='indep_2',
    coluna_y='target',
)
df_4_copy.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 0       6.37            0            1            1            0            0
# 154    22.80            1            0            0            0            1
#
#      target
# 93        9
# 20       36
# 177      13
# 0        21
# 154      40

# %%
sns.scatterplot(
    x='indep_2',
    y='target',
    s=20,
    data=df_4_copy
)

dados_reta = [reg_simpl.params[0], reg_simpl.params[1]]
df_4_copy['target_cal'] = df_4_copy['indep_2'].apply(curva.reta, args=dados_reta)
sns.lineplot(
    x='indep_2',
    y='target_cal',
    data=df_4_copy,
    c='r',
)
for n in range(5):
    index = df_4_copy['indep_2'].sample(1).index[0]
    x = df_4_copy['indep_2'][index]
    y = df_4_copy['target_cal'][index]
    d = df_4_copy['target'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=.5,
        head_length=2,
        length_includes_head=True,
        color='r',
    )

dados_reta = [df_4_copy['target'].mean(), 0]
df_4_copy['target_media'] = df_4_copy['indep_2'].apply(curva.reta, args=dados_reta)
sns.lineplot(
    x='indep_2',
    y='target_media',
    data=df_4_copy,
    c='g',
)
for n in range(5):
    index = df_4_copy['indep_2'].sample(1).index[0]
    x = df_4_copy['indep_2'][index]
    y = df_4_copy['target_media'][index]
    d = df_4_copy['target'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=.5,
        head_length=2,
        length_includes_head=True,
        color='g',
    )

plt.title('Variável independete 1 vs Target')

plt.xlabel('Independete')
plt.xlim(df_4_copy['indep_2'].min()-1, df_4_copy['indep_2'].max()+1)

plt.ylabel('Target')
plt.ylim(df_4_copy['target'].min()-1, df_4_copy['target'].max()+1)

plt.show()

# %%
df_reg_test['linear_simples'] = reg_simpl.predict(df_reg_test['indep_2'])
df_reg_test.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 132     5.53            0            1            1            0            0
# 143     5.61            0            1            1            0            0
# 121     5.37            0            1            1            0            0
# 91      7.22            0            1            1            0            0
# 74     12.19            0            1            0            1            0
#
#      target  linear_simples
# 132      18       13.792351
# 143      14       13.911224
# 121      14       13.554604
# 91       22       16.303549
# 74       20       23.688553

# %%
def r2_score(y_true, y_pred):
    """
    Calculates the coefficient of determination (R-squared) manually.

    Args:
        y_true (list or np.array): The true (observed) values.
        y_pred (list or np.array): The predicted values from the model.

    Returns:
        float: The R-squared value.
    """
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    # Calculate the mean of the true values
    y_true_mean = np.mean(y_true)

    # Calculate the Sum of Squares of Residuals (SS_res)
    ss_res = np.sum((y_true - y_pred) ** 2)

    # Calculate the Total Sum of Squares (SS_tot)
    ss_tot = np.sum((y_true - y_true_mean) ** 2)

    # Handle the case where SS_tot is zero (e.g., all y_true values are the same)
    if ss_tot == 0:
        return 1.0  # R-squared is 1 if there's no variance in y_true

    # Calculate R-squared
    r_squared = 1 - (ss_res / ss_tot)

    return r_squared

# %%
def metricas(
        y_true: pd.Series,
        y_pred: pd.Series,
        nome_modelo: str = None) -> None:
    '''
        Função que calcula as métricas de erro
    '''
    df_test = pd.DataFrame()
    df_test['y_true'] = y_true
    df_test['y_pred'] = y_pred

    r_cal, r_cal_p = spearmanr(df_test['y_true'], df_test['y_pred'])
    r2_cal = r2_score(df_test['y_true'], df_test['y_pred'])
    mae_cal = mean_absolute_error(df_test['y_true'], df_test['y_pred'])
    rmse_cal = mean_squared_error(df_test['y_true'], df_test['y_pred'])
    mape_cal = mean_absolute_percentage_error(
                                                    df_test['y_true'],
                                                    df_test['y_pred']
                                            )

    mensagem = f'''
R Spearman: {r_cal:.4f}
R p-value: {r_cal_p:.4f}
R2: {r2_cal:.4f}
MAE: {mae_cal:.4f}
RMSE: {rmse_cal:.4f}
MAPE: {mape_cal:.4f}
    '''
    
    p = sns.jointplot(
        x='y_true',
        y='y_pred',
        data=df_test,
        kind='reg',
    )
    p.fig.suptitle(f"Correlação predito / observado - {nome_modelo}", y=1.02)
    plt.text(
        0.05,
        0.99,
        mensagem,
        transform=p.ax_joint.transAxes,
        fontsize=12,
        ha='left',
        va='top'
    )
    plt.xlabel('Observado')
    plt.ylabel('Predito')
    plt.show()

    return None

# %%
metricas(df_reg_test['target'], df_reg_test['linear_simples'], nome_modelo='Regressão Simples')

# %%
df_reg_test.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 132     5.53            0            1            1            0            0
# 143     5.61            0            1            1            0            0
# 121     5.37            0            1            1            0            0
# 91      7.22            0            1            1            0            0
# 74     12.19            0            1            0            1            0
#
#      target  linear_simples
# 132      18       13.792351
# 143      14       13.911224
# 121      14       13.554604
# 91       22       16.303549
# 74       20       23.688553

# %% [markdown]
# ## Regressão Linear Multipla

# %%
modelo = '''
                target ~ 
                indep_2 +
                indep_3_max +
                indep_3_min +
                indep_4_min +
                indep_4_med +
                indep_4_max
        '''
reg_mult = smf.ols(modelo, data=df_reg).fit()
reg_mult.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.788
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     88.08
# Date:                Thu, 30 Jul 2026   Prob (F-statistic):           4.19e-31
# Time:                        19:09:04   Log-Likelihood:                -304.67
# No. Observations:                 100   AIC:                             619.3
# Df Residuals:                      95   BIC:                             632.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.1281      1.444      3.551      0.001       2.261       7.995
# indep_2         1.1540      0.212      5.433      0.000       0.732       1.576
# indep_3_max     3.7028      0.909      4.072      0.000       1.898       5.508
# indep_3_min     1.4253      0.881      1.617      0.109      -0.324       3.175
# indep_4_min    -0.8185      1.158     -0.707      0.481      -3.118       1.481
# indep_4_med     1.5137      0.755      2.004      0.048       0.014       3.013
# indep_4_max     4.4329      2.371      1.870      0.065      -0.274       9.140
# ==============================================================================
# Omnibus:                        0.436   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.804   Jarque-Bera (JB):                0.345
# Skew:                          -0.143   Prob(JB):                        0.842
# Kurtosis:                       2.961   Cond. No.                     1.94e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.13e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
modelo = '''
                target ~ 
                indep_2 +
                indep_3_max +
                indep_4_med
        '''
reg_mult = smf.ols(modelo, data=df_reg).fit()
reg_mult.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.782
# Model:                            OLS   Adj. R-squared:                  0.775
# Method:                 Least Squares   F-statistic:                     115.0
# Date:                Thu, 30 Jul 2026   Prob (F-statistic):           1.16e-31
# Time:                        19:09:04   Log-Likelihood:                -305.92
# No. Observations:                 100   AIC:                             619.8
# Df Residuals:                      96   BIC:                             630.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       4.3369      1.330      3.261      0.002       1.697       6.977
# indep_2         1.4588      0.081     18.105      0.000       1.299       1.619
# indep_3_max     2.2713      1.067      2.130      0.036       0.154       4.388
# indep_4_med     0.6077      1.148      0.529      0.598      -1.672       2.887
# ==============================================================================
# Omnibus:                        0.132   Durbin-Watson:                   1.785
# Prob(Omnibus):                  0.936   Jarque-Bera (JB):                0.033
# Skew:                          -0.044   Prob(JB):                        0.984
# Kurtosis:                       2.994   Cond. No.                         41.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_reg_test['linear_multi'] = reg_mult.predict(df_reg_test[['indep_2','indep_3_max', 'indep_4_med']])
df_reg_test.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 132     5.53            0            1            1            0            0
# 143     5.61            0            1            1            0            0
# 121     5.37            0            1            1            0            0
# 91      7.22            0            1            1            0            0
# 74     12.19            0            1            0            1            0
#
#      target  linear_simples  linear_multi
# 132      18       13.792351     12.404122
# 143      14       13.911224     12.520826
# 121      14       13.554604     12.170714
# 91       22       16.303549     14.869497
# 74       20       23.688553     22.727430

# %%
metricas(df_reg_test['target'], df_reg_test['linear_multi'], nome_modelo='Regressão Múltipla')

# %%
df_reg['linear_simples'] = reg_simpl.predict(df_reg['indep_2'])
df_reg['linear_multi'] = reg_mult.predict(df_reg[['indep_2', 'indep_3_max', 'indep_4_med']])
df_reg.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target  linear_simples  linear_multi
# 53       41       41.772154     42.144690
# 93        9       17.536860     16.687991
# 20       36       35.174686     35.667611
# 177      13       17.061367     17.884818
# 26       17       14.802774     15.667440

# %%
metricas(df_reg['target'], df_reg['linear_simples'], nome_modelo='Regressão Simples')

# %%
metricas(df_reg['target'], df_reg['linear_multi'], nome_modelo='Regressão Múltipla')

# %%
dump(df_reg, './data/05_aula_df_11')
df_12 = load('./data/05_aula_df_11')

df_12.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target  linear_simples  linear_multi
# 53       41       41.772154     42.144690
# 93        9       17.536860     16.687991
# 20       36       35.174686     35.667611
# 177      13       17.061367     17.884818
# 26       17       14.802774     15.667440

# %% [markdown]
# ## SVM

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
df_reg_train, df_reg_test, X_test, X_train, y_test, y_train = train_test_df_split(df=df_12, indep=indep)
# Out:
# df_train: (70, 9)
# df_test: (30, 9)
# X_train: (70, 6)
# X_test: (30, 6)
# y_train: (70,)
# y_test: (30,)

# %%
kernel = ['linear', 'poly', 'rbf', 'sigmoid'] 
C = [0.1, 1, 10, 100]

svm = SVC()

param_grid = {
    'C': C,
    'gamma': [0.001, 0.01, 0.1, 1],
    'kernel': kernel,
}

grid_svm = GridSearchCV(
    estimator=svm,
    param_grid=param_grid,
    cv=2,
    scoring='r2',
    verbose=1,
    n_jobs=-1
)

grid_svm.fit(X_train, y_train)
grid_svm.best_params_
# Out:
# Fitting 2 folds for each of 64 candidates, totalling 128 fits
# /usr/local/lib/python3.10/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}

# %%
svm = SVC()
svm.set_params(**grid_svm.best_params_)
svm.fit(X_train, y_train)

svm.score(X_test, y_test)
# Out:
# 0.04285714285714286

# %%
c = -3
df_reg_test['svm'] = svm.predict(df_reg_test[df_reg_test.columns[:c]])
df_reg_test.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 132     5.53            0            1            1            0            0
# 143     5.61            0            1            1            0            0
# 121     5.37            0            1            1            0            0
# 91      7.22            0            1            1            0            0
# 74     12.19            0            1            0            1            0
#
#      target  linear_simples  linear_multi  svm
# 132      18       13.792351     12.404122   14
# 143      14       13.911224     12.520826   14
# 121      14       13.554604     12.170714   14
# 91       22       16.303549     14.869497    9
# 74       20       23.688553     22.727430   20

# %%
metricas(df_reg_test['target'], df_reg_test['svm'], nome_modelo='SVM')

# %%
df_12['svm'] = svm.predict(df_12[df_12.columns[:c]])
df_12.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target  linear_simples  linear_multi  svm
# 53       41       41.772154     42.144690   41
# 93        9       17.536860     16.687991    9
# 20       36       35.174686     35.667611   41
# 177      13       17.061367     17.884818    9
# 26       17       14.802774     15.667440   18

# %%
metricas(df_12['target'], df_12['svm'], nome_modelo='SVM')

# %%
dump(df_12, './data/05_aula_df_12')
df_13 = load('./data/05_aula_df_12')

df_13.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target  linear_simples  linear_multi  svm
# 53       41       41.772154     42.144690   41
# 93        9       17.536860     16.687991    9
# 20       36       35.174686     35.667611   41
# 177      13       17.061367     17.884818    9
# 26       17       14.802774     15.667440   18

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
df_13.describe()
# Out:
#           indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  \
# count  100.000000   100.000000   100.000000   100.000000   100.000000
# mean    12.149100     0.440000     0.560000     0.340000     0.330000
# std      6.699893     0.498888     0.498888     0.476095     0.472582
# min     -0.960000     0.000000     0.000000     0.000000     0.000000
# 25%      6.875000     0.000000     0.000000     0.000000     0.000000
# 50%     10.155000     0.000000     1.000000     0.000000     0.000000
# 75%     19.432500     1.000000     1.000000     1.000000     1.000000
# max     26.680000     1.000000     1.000000     1.000000     1.000000
#
#        indep_4_max      target  linear_simples  linear_multi         svm
# count   100.000000  100.000000      100.000000    100.000000  100.000000
# mean      0.330000   23.260000       23.627779     23.260000   23.120000
# std       0.472582   11.106118        9.955480      9.822869   11.991815
# min       0.000000    3.000000        4.148754      5.207832    8.000000
# 25%       0.000000   14.000000       15.790908     15.437679   14.000000
# 50%       0.000000   22.000000       20.664714     20.930905   20.000000
# 75%       1.000000   33.250000       34.450302     33.622393   41.000000
# max       1.000000   44.000000       45.219480     45.529110   41.000000

# %%
try:
    nb = MultinomialNB()

    parametros = {
        'alpha' : [1.0, 0.5, 0.1, 0.01],
        'fit_prior': [True, False],
    }

    grid_nb = GridSearchCV(
                            estimator=nb,
                            param_grid=parametros,
                            scoring='r2',
                            verbose=False,
                            cv=2
    ).fit(X_train, y_train)

    grid_nb.best_params_
except Exception as e:
    print(f"Erro ao treinar o modelo: {e}")
# Out:
# Erro ao treinar o modelo: Negative values in data passed to MultinomialNB (input X)
# /usr/local/lib/python3.10/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:547: FitFailedWarning:
# 8 fits failed out of a total of 16.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/site-packages/sklearn/naive_bayes.py", line 759, in fit
#     self._count(X, Y)
#   File "/usr/local/lib/python3.10/site-packages/sklearn/naive_bayes.py", line 881, in _count
#     check_non_negative(X, "MultinomialNB (input X)")
#   File "/usr/local/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1650, in check_non_negative
#     raise ValueError("Negative values in data passed to %s" % whom)
# ValueError: Negative values in data passed to MultinomialNB (input X)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan]
#   warnings.warn(

# %%
df_13['indep_2'] = df_13['indep_2'].apply(lambda x: x*-1 if x < 0 else x)
df_13['indep_2'].describe()
# Out:
# count    100.000000
# mean      12.168300
# std        6.664605
# min        0.960000
# 25%        6.875000
# 50%       10.155000
# 75%       19.432500
# max       26.680000
# Name: indep_2, dtype: float64

# %%
df_13_train, df_13_test, X_test, X_train, y_test, y_train = train_test_df_split(df=df_13, indep=indep)
# Out:
# df_train: (70, 10)
# df_test: (30, 10)
# X_train: (70, 6)
# X_test: (30, 6)
# y_train: (70,)
# y_test: (30,)

# %%
nb = MultinomialNB()

parametros = {
    'alpha' : [1.0, 0.5, 0.1, 0.01],
    'fit_prior': [True, False],
}

grid_nb = GridSearchCV(
                        estimator=nb,
                        param_grid=parametros,
                        scoring='r2',
                        verbose=False,
                        cv=2
).fit(X_train, y_train)

grid_nb.best_params_
# Out:
# /usr/local/lib/python3.10/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# {'alpha': 0.01, 'fit_prior': True}

# %%
nb = MultinomialNB()
nb.set_params(**grid_nb.best_params_)
nb.fit(X_train, y_train)

nb.score(X_test, y_test)
# Out:
# 0.02857142857142857

# %%
c -= 1
df_reg_test['nb'] = nb.predict(df_reg_test[df_reg_test.columns[:c]])
df_reg_test.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 132     5.53            0            1            1            0            0
# 143     5.61            0            1            1            0            0
# 121     5.37            0            1            1            0            0
# 91      7.22            0            1            1            0            0
# 74     12.19            0            1            0            1            0
#
#      target  linear_simples  linear_multi  svm  nb
# 132      18       13.792351     12.404122   14  14
# 143      14       13.911224     12.520826   14  14
# 121      14       13.554604     12.170714   14   8
# 91       22       16.303549     14.869497    9  14
# 74       20       23.688553     22.727430   20  20

# %%
metricas(df_reg_test['target'], df_reg_test['nb'], nome_modelo='Naive Bayes')

# %%
df_13['nb'] = nb.predict(df_13[df_13.columns[:c]])
df_13.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target  linear_simples  linear_multi  svm  nb
# 53       41       41.772154     42.144690   41  41
# 93        9       17.536860     16.687991    9  23
# 20       36       35.174686     35.667611   41  41
# 177      13       17.061367     17.884818    9  17
# 26       17       14.802774     15.667440   18  17

# %%
metricas(df_13['target'], df_13['nb'], nome_modelo='Naive Bayes')

# %%
dump(df_13, './data/05_aula_df_13')
df_14 = load('./data/05_aula_df_13')

df_14.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target  linear_simples  linear_multi  svm  nb
# 53       41       41.772154     42.144690   41  41
# 93        9       17.536860     16.687991    9  23
# 20       36       35.174686     35.667611   41  41
# 177      13       17.061367     17.884818    9  17
# 26       17       14.802774     15.667440   18  17

# %% [markdown]
# ## Redes Neurais

# %%
# TensorFlow e tf.keras
import tensorflow as tf
from tensorflow import keras

# %%
df_14_train, df_14_test, X_test, X_train, y_test, y_train = train_test_df_split(df=df_14, indep=indep)
# Out:
# df_train: (70, 11)
# df_test: (30, 11)
# X_train: (70, 6)
# X_test: (30, 6)
# y_train: (70,)
# y_test: (30,)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(X_train.shape[1],)),
    keras.layers.Dense(64, activation='softmax'),
    keras.layers.Dense(32, activation='softmax'),
    keras.layers.Dense(1, activation='linear'),
])

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(
    optimizer='sgd', # Stochastic Gradient Descent (SGD).
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 6)                 0
#
#  dense_3 (Dense)             (None, 64)                448
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    verbose=0
)

# %%
pd.DataFrame(model.history.history).plot(
    title='Loss and Accuracy over Epochs',
    xlabel='Epochs',
    ylabel='Value',
)
plt.show()

# %%
c -= 1
df_reg_test['NN'] = model.predict(df_reg_test[df_reg_test.columns[:c]])
df_reg_test.head()
# Out:
# 1/1 [==============================] - 0s 51ms/step
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 132     5.53            0            1            1            0            0
# 143     5.61            0            1            1            0            0
# 121     5.37            0            1            1            0            0
# 91      7.22            0            1            1            0            0
# 74     12.19            0            1            0            1            0
#
#      target  linear_simples  linear_multi  svm  nb         NN
# 132      18       13.792351     12.404122   14  14  18.981045
# 143      14       13.911224     12.520826   14  14  18.981319
# 121      14       13.554604     12.170714   14   8  18.980511
# 91       22       16.303549     14.869497    9  14  18.988049
# 74       20       23.688553     22.727430   20  20  19.015673

# %%
metricas(df_reg_test['target'], df_reg_test['NN'], nome_modelo='Neural Network')

# %%
df_14['NN'] = model.predict(df_14[df_14.columns[:c]])
df_14.head()
# Out:
# 4/4 [==============================] - 0s 2ms/step
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target  linear_simples  linear_multi  svm  nb         NN
# 53       41       41.772154     42.144690   41  41  19.023903
# 93        9       17.536860     16.687991    9  23  18.997250
# 20       36       35.174686     35.667611   41  41  19.023544
# 177      13       17.061367     17.884818    9  17  18.992439
# 26       17       14.802774     15.667440   18  17  18.984976

# %%
metricas(df_14['target'], df_14['NN'], nome_modelo='Neural Network')

# %%
dump(df_14, './data/05_aula_df_14')
df_15 = load('./data/05_aula_df_14')

df_15.head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target  linear_simples  linear_multi  svm  nb         NN
# 53       41       41.772154     42.144690   41  41  19.023903
# 93        9       17.536860     16.687991    9  23  18.997250
# 20       36       35.174686     35.667611   41  41  19.023544
# 177      13       17.061367     17.884818    9  17  18.992439
# 26       17       14.802774     15.667440   18  17  18.984976

# %% [markdown]
# ## Redes Neurais + GridSearchCV

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %%
df_15_train, df_15_test, X_test, X_train, y_test, y_train = train_test_df_split(df=df_15, indep=indep)
# Out:
# df_train: (70, 12)
# df_test: (30, 12)
# X_train: (70, 6)
# X_test: (30, 6)
# y_train: (70,)
# y_test: (30,)

# %%
# 1. Função de Criação do Modelo
def create_model(optimizer, activation1, activation2):
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=(X_train.shape[1],)),
        keras.layers.Dense(64, activation=activation1),
        keras.layers.Dense(32, activation=activation2),
        keras.layers.Dense(1, activation='linear'),
    ])

    model.compile(
        optimizer=optimizer, # Stochastic Gradient Descent (SGD).
        loss='mse',
        metrics=['mae']
    )
    return model

# %%
# 2. Envolvimento do Modelo Keras
# O build_fn aponta para a função que cria o modelo.
# Você também pode fixar hiperparâmetros de treinamento como epochs e batch_size
# dentro de KerasRegressor.
keras_model = KerasRegressor(build_fn=create_model, verbose=0)

# %%
# 3. Definição da Grade de Hiperparâmetros
param_grid = {
    'optimizer': ['SGD', 'RMSprop', 'Adam'],
    'epochs': [10, 50], # Hiperparâmetro passado para .fit() do Keras
    'batch_size': [5, 10, 30], # Hiperparâmetro passado para .fit() do Keras
    'activation1': ['relu', 'tanh', 'sigmoid', 'softmax'], # Hiperparâmetro passado para a camada Dense
    'activation2': ['relu', 'tanh', 'sigmoid', 'softmax'], # Hiperparâmetro passado para a camada Dense
}

# %%
# Define the EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='loss',  # Monitor validation loss
    mode='min',          # Minimize validation loss
    patience=10,         # Stop after 10 epochs with no improvement
    min_delta=0.001,     # Minimum change to be considered an improvement
    restore_best_weights=True # Restore best weights
)

# %%
# 4. Criação e Execução do GridSearchCV
grid = GridSearchCV(estimator=keras_model, param_grid=param_grid, n_jobs=-1, cv=3, verbose=0)

# O gridsearch fará o fit e o cross-validation
grid_result = grid.fit(X_train, y_train, callbacks=[early_stopping])
# Out:
# 2026-07-30 19:09:46.883398: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different 2026-07-30 19:09:46.883416: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different 2026-07-30 19:09:46.883415: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different 2026-07-30 19:09:46.883402: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environmennumerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environmennumerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# t variable `TF_ENABLE_ONEDNN_OPTS=0`.
# t variable `TF_ENABLE_ONEDNN_OPTS=0`.
# numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:46.884489: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:46.886835: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:46.888638: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not b2026-07-30 19:09:46.888638: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# e used.
# 2026-07-30 19:09:46.889094: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:46.892227: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:46.893109: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not b2026-07-30 19:09:46.893192: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# e used.
# 2026-07-30 19:09:46.910704: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:46.913457: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:46.950002: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:46.955538: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:46.987540: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:46.988731: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:46.989676: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:46.990524: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:46.992815: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:46.994025: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.000927: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.001617: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.013368: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:47.024185: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:47.024826: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.034678: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.035238: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.035904: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.040841: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.042141: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.046734: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:47.047896: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:47.053092: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not b2026-07-30 19:09:47.053102: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# e used.
# 2026-07-30 19:09:47.066901: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.068994: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.073010: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:47.077872: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.128679: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-30 19:09:47.135576: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.175970: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.177453: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.195420: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.196338: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.259987: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.261533: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.271472: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.273158: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.534512: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.535796: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.547565: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.579191: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-30 19:09:47.633085: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-30 19:09:47.634737: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:09:49.265787: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:09:49.392250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-07-30 19:09:49.471360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:09:49.497503: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:09:49.779369: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-07-30 19:09:49.846850: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:09:49.938337: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:09:50.203136: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-07-30 19:09:50.203299: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-07-30 19:09:50.310868: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-07-30 19:09:50.457360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-07-30 19:09:50.841371: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-07-30 19:09:50.958209: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-07-30 19:09:51.042997: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:09:59.856745: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:10:00.795343: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:10:01.599586: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:10:02.961675: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:10:03.937899: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:10:05.613381: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:10:07.479798: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:10:08.935635: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x7749f413c550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:10:10.763449: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:10:12.580698: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x7749f413e710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x76f14043d2d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-07-30 19:10:14.186529: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x76f14043c550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x7ea490265480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2026-07-30 19:10:18.314976: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x77a3fc1ed2d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2026-07-30 19:10:19.242615: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-07-30 19:10:19.397423: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x733794729750> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x7ea490266f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x7c7e30110280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x77a3fc1eeb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_test_function.<locals>.test_function at 0x7c7e30112950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_test_function.<locals>.test_function at 0x73379472af80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x72d2d01e9480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x73ed045715a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x7088ec799480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x7088ec79add0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x72d2d01eadd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_test_function.<locals>.test_function at 0x73ed04572ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x7cb6fc4a13f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x7131341813f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_test_function.<locals>.test_function at 0x713134182cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_test_function.<locals>.test_function at 0x7cb6fc4a30a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x79fa84571240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x792864065240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_test_function.<locals>.test_function at 0x79fa84572ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x72e1542c15a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x72e1542c2f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_test_function.<locals>.test_function at 0x792864066ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
best_params = grid_result.best_params_
best_params
# Out:
# {'activation1': 'relu',
#  'activation2': 'relu',
#  'batch_size': 5,
#  'epochs': 50,
#  'optimizer': 'RMSprop'}

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(X_train.shape[1],)),
    keras.layers.Dense(64, activation=best_params['activation1']),
    keras.layers.Dense(32, activation=best_params['activation2']),
    keras.layers.Dense(1, activation='linear'),
])

model.compile(
    optimizer=best_params['optimizer'], # Stochastic Gradient Descent (SGD).
    loss='mse',
    metrics=['mae']
)
model.fit(
    X_train,
    y_train,
    epochs=best_params['epochs'],
    batch_size=best_params['batch_size'],
    callbacks=[early_stopping],
    verbose=0
)

# %%
pd.DataFrame(model.history.history).plot(
    title='Loss and Accuracy over Epochs',
    xlabel='Epochs',
    ylabel='Value',
)
plt.show()

# %%
c -= 1
df_reg_test['NN-GS'] = model.predict(df_reg_test[df_reg_test.columns[:c]])
df_reg_test.head()
# Out:
# 1/1 [==============================] - 0s 49ms/step
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 132     5.53            0            1            1            0            0
# 143     5.61            0            1            1            0            0
# 121     5.37            0            1            1            0            0
# 91      7.22            0            1            1            0            0
# 74     12.19            0            1            0            1            0
#
#      target  linear_simples  linear_multi  svm  nb         NN      NN-GS
# 132      18       13.792351     12.404122   14  14  18.981045  11.666666
# 143      14       13.911224     12.520826   14  14  18.981319  11.786200
# 121      14       13.554604     12.170714   14   8  18.980511  11.427600
# 91       22       16.303549     14.869497    9  14  18.988049  14.191797
# 74       20       23.688553     22.727430   20  20  19.015673  21.763472

# %%
df_reg_test.dropna().head()
# Out:
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 132     5.53            0            1            1            0            0
# 143     5.61            0            1            1            0            0
# 121     5.37            0            1            1            0            0
# 91      7.22            0            1            1            0            0
# 74     12.19            0            1            0            1            0
#
#      target  linear_simples  linear_multi  svm  nb         NN      NN-GS
# 132      18       13.792351     12.404122   14  14  18.981045  11.666666
# 143      14       13.911224     12.520826   14  14  18.981319  11.786200
# 121      14       13.554604     12.170714   14   8  18.980511  11.427600
# 91       22       16.303549     14.869497    9  14  18.988049  14.191797
# 74       20       23.688553     22.727430   20  20  19.015673  21.763472

# %%
try:
    metricas(df_reg_test['target'], df_reg_test['NN-GS'], nome_modelo='Neural Network')
except Exception as e:
    print(f"Erro ao calcular métricas: {e}")

# %%
df_14['NN'] = model.predict(df_14[df_14.columns[:c]])
df_14.head()
# Out:
# 4/4 [==============================] - 0s 4ms/step
#      indep_2  indep_3_max  indep_3_min  indep_4_min  indep_4_med  indep_4_max  \
# 53     24.36            1            0            0            0            1
# 93      8.05            0            1            0            1            0
# 20     19.92            1            0            0            0            1
# 177     7.73            1            0            1            0            0
# 26      6.21            1            0            1            0            0
#
#      target  linear_simples  linear_multi  svm  nb         NN
# 53       41       41.772154     42.144690   41  41  40.476067
# 93        9       17.536860     16.687991    9  23  15.567438
# 20       36       35.174686     35.667611   41  41  33.846451
# 177      13       17.061367     17.884818    9  17  16.948444
# 26       17       14.802774     15.667440   18  17  14.716064

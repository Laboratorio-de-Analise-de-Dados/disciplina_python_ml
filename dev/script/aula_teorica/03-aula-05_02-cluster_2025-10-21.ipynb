# %% [markdown]
# # Algoritmos

# %% [markdown]
# ## Gerando dados

# %%
from joblib import load, dump

# %%
import os

os.listdir("./")
# Out:
# ['00-divisão_dados_2025-02-01.ipynb',
#  '01-aula_2025-10-13.ipynb',
#  '02-aula-04_2025-10-14.ipynb',
#  '03-aula-05_01-dados_2025-10-21.ipynb',
#  '03-aula-05_02-cluster_2025-10-21.ipynb',
#  '03-aula-05_03-classif_2025-10-21.ipynb',
#  '03-aula-05_04-regressão_2025-11-15.ipynb',
#  'data',
#  'SMOTE.ipynb',
#  'src',
#  'ydata-profiling.ipynb']

# %%
df_1 = load('./data/05_aula_df_1')
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 53   41  18  41.101260  19.359319    24.359319            23             8
# 93    9   2   9.876045   3.050423     8.050423            23             9
# 20   37  16  36.714018  14.920509    19.920509            11             0
# 177  15   5  13.314530   2.728269     7.728269            42            21
# 26   15   5  17.686336   1.206506     6.206506             9             5
#
#      class style style_2
# 53   False     o       +
# 93    True     +       o
# 20   False     o       +
# 177  False     o       o
# 26   False     o       o

# %% [markdown]
# ## k-means

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
x = 'x_noise'
y = 'y_noise_new'
s = 10
sns.scatterplot(
    x=x,
    y=y,
    s=s,
    data=df_1,
)
plt.title('Scatter Plot de X/Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
def ponto_estrela(df_sample: pd.DataFrame, x: str, y: str) -> tuple:
    x_estrela = np.random.randint(
        np.min(df_sample[x]),
        np.max(df_sample[x]),
    )
    y_estrela = np.random.randint(
        np.min(df_sample[y]),
        np.max(df_sample[y]),
    )
    return x_estrela, y_estrela

def seta_estrela(
        df_sample: pd.DataFrame,
        x: str,
        y: str,
        color: str = 'g',
        seta: bool = False,
        n_setas: int = 5) -> None:
    sns.scatterplot(
        x=x,
        y=y,
        s=s,
        color='b',
        data=df_sample,
    )
    x_estrela, y_estrela = ponto_estrela(df_sample, x, y)
    plt.plot(
        x_estrela,
        y_estrela,
        '*' + color,
        markersize=15
    )
    if seta:
        for _ in range(n_setas):
            index = df_sample[x].sample(1).index[0]
            dx = df_sample[x][index] - x_estrela
            dy = df_sample[y][index] - y_estrela
            plt.arrow(
                x_estrela,
                y_estrela, 
                dx,
                dy,
                head_width=1,
                head_length=1,
                length_includes_head=True,
                color=color,
            )
    return None

# %%
grafico = {
    "df_sample": df_1,
    'x': 'x_noise',
    'y': 'y_noise_new'
}
seta_estrela(**grafico)
plt.title('Scatter Plot de X/Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
grafico = {
    "df_sample": df_1,
    'x': 'x_noise',
    'y': 'y_noise_new',
    'seta': True,
    'n_setas': 1
}
seta_estrela(**grafico)
plt.title('Scatter Plot de X/Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
grafico = {
    "df_sample": df_1,
    'x': 'x_noise',
    'y': 'y_noise_new',
    'seta': True,
}
seta_estrela(**grafico)
plt.title('Scatter Plot de X/Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
grafico = {
    "df_sample": df_1,
    'x': 'x_noise',
    'y': 'y_noise_new',
    'seta': True,
}
seta_estrela(**grafico)
grafico = {
    "df_sample": df_1,
    'x': 'x_noise',
    'y': 'y_noise_new',
    'color': 'r',
    'seta': True,
}
seta_estrela(**grafico)
plt.title('Scatter Plot de X/Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df_1[[x, y]])
scaled_features[:5]
# Out:
# array([[ 1.57364483,  1.8314633 ],
#        [-1.2540686 , -0.61485802],
#        [ 1.17634214,  1.16564535],
#        [-0.94268406, -0.66318093],
#        [-0.54677913, -0.89144423]])

# %%
df_1[x+'_scaled'] = scaled_features[:, 0]
df_1[y+'_scaled'] = scaled_features[:, 1]
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 53   41  18  41.101260  19.359319    24.359319            23             8
# 93    9   2   9.876045   3.050423     8.050423            23             9
# 20   37  16  36.714018  14.920509    19.920509            11             0
# 177  15   5  13.314530   2.728269     7.728269            42            21
# 26   15   5  17.686336   1.206506     6.206506             9             5
#
#      class style style_2  x_noise_scaled  y_noise_new_scaled
# 53   False     o       +        1.573645            1.831463
# 93    True     +       o       -1.254069           -0.614858
# 20   False     o       +        1.176342            1.165645
# 177  False     o       o       -0.942684           -0.663181
# 26   False     o       o       -0.546779           -0.891444

# %%
x_scaled = 'x_noise_scaled'
y_scaled = 'y_noise_new_scaled'
inertia = []
for i in range(1, 11): # Test k from 1 to 10
    kmeans = KMeans(n_clusters=i, random_state=42, n_init='auto')
    kmeans.fit(df_1[[x_scaled, y_scaled]])
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 11), inertia)
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# %%
# Inicializar uma lista vazia que vai conter os valores da silueta média
siluetas = []
# Este é o número máximo de grupos que vamos testar
max_clusters = 10

# O loop percorre de 2 até o máximo de clusters
for n_clusters in range(2, max_clusters+1):
    # Aqui rodamos o k-means
    km = KMeans(n_clusters=n_clusters).fit(df_1[[x_scaled, y_scaled]])
    # Aqui calculamos a silueta e guardamos o resultado na lista 'siluetas'
    siluetas.append(silhouette_score(df_1[[x_scaled, y_scaled]], km.labels_))
siluetas[:5]
# Out:
# [0.6123335974505002,
#  0.5281648420447782,
#  0.46967323872339106,
#  0.44696076878332314,
#  0.41540176199237705]

# %%
df_silueta = pd.DataFrame({'n_clusters': list(range(2, max_clusters+1)), 'silhueta_média': siluetas})
df_silueta
# Out:
#    n_clusters  silhueta_média
# 0           2        0.612334
# 1           3        0.528165
# 2           4        0.469673
# 3           5        0.446961
# 4           6        0.415402
# 5           7        0.462278
# 6           8        0.439010
# 7           9        0.365894
# 8          10        0.393521

# %%
df_silueta.plot.line(
    x='n_clusters',
    y='silhueta_média',
    marker='o'
)
plt.title('Método da Silhueta')
plt.ylabel('Silhueta Média')
plt.xlabel('Número de Clusters')
plt.show()

# %%
optimal_k = df_silueta[df_silueta['silhueta_média'] == df_silueta['silhueta_média'].max()]['n_clusters'].values[0]
optimal_k
# Out:
# 2

# %%
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init='auto')
kmeans.fit(scaled_features)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
df_1['k-means'] = [1 if i == 0 else 0 for i in kmeans.labels_]
sns.scatterplot(
    x=x,
    y=y,
    s=s,
    hue='k-means',
    data=df_1
)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-Means Clustering Results')
plt.show()

# %% [markdown]
# ## DBSCAM

# %%
from sklearn.cluster import DBSCAN

# %%
# Create a DBSCAN instance with specified parameters
min_samples = [1, 2, 3, 4, 5, 6]
eps = [0.1, 0.2, 0.25, 0.3, 0.4, 0.5]

for sample in min_samples:
    for ep in eps:
        db = DBSCAN(eps=ep, min_samples=sample)
        # Fit the model to the data and predict cluster labels
        clusters = db.fit_predict(df_1[[x_scaled, y_scaled]])
        cluster, num = np.unique(clusters, return_counts=True)
        if len(cluster) == 2 or len(cluster) == 3:
            print("-----"*20)
            print(f"DBSCAN with eps={ep} and min_samples={sample}")
            print(cluster, num)
# Out:
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.5 and min_samples=1
# [0 1] [28 72]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.4 and min_samples=2
# [-1  0  1] [ 3 27 70]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.5 and min_samples=2
# [0 1] [28 72]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.4 and min_samples=3
# [-1  0  1] [ 3 27 70]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.5 and min_samples=3
# [0 1] [28 72]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.1 and min_samples=4
# [-1  0  1] [92  4  4]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.3 and min_samples=4
# [-1  0  1] [13 25 62]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.4 and min_samples=4
# [-1  0  1] [ 3 27 70]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.5 and min_samples=4
# [-1  0  1] [ 1 28 71]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.2 and min_samples=5
# [-1  0  1] [51 36 13]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.4 and min_samples=5
# [-1  0  1] [ 3 27 70]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.5 and min_samples=5
# [-1  0  1] [ 1 28 71]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.4 and min_samples=6
# [-1  0  1] [ 4 27 69]
# ----------------------------------------------------------------------------------------------------
# DBSCAN with eps=0.5 and min_samples=6
# [-1  0  1] [ 1 28 71]

# %%
db = DBSCAN(eps=0.3, min_samples=4)
# Fit the model to the data and predict cluster labels
df_1['DBSCAN_1'] = db.fit_predict(df_1[[x_scaled, y_scaled]])

db = DBSCAN(eps=0.5, min_samples=3)
# Fit the model to the data and predict cluster labels
df_1['DBSCAN_2'] = db.fit_predict(df_1[[x_scaled, y_scaled]])
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 53   41  18  41.101260  19.359319    24.359319            23             8
# 93    9   2   9.876045   3.050423     8.050423            23             9
# 20   37  16  36.714018  14.920509    19.920509            11             0
# 177  15   5  13.314530   2.728269     7.728269            42            21
# 26   15   5  17.686336   1.206506     6.206506             9             5
#
#      class style style_2  x_noise_scaled  y_noise_new_scaled  k-means  \
# 53   False     o       +        1.573645            1.831463        0
# 93    True     +       o       -1.254069           -0.614858        1
# 20   False     o       +        1.176342            1.165645        0
# 177  False     o       o       -0.942684           -0.663181        1
# 26   False     o       o       -0.546779           -0.891444        1
#
#      DBSCAN_1  DBSCAN_2
# 53          0         0
# 93          1         1
# 20          0         0
# 177         1         1
# 26          1         1

# %%
# Visualize the results
sns.scatterplot(
    x=x,
    y=y,
    s=s,
    hue='DBSCAN_1',
    data=df_1
)
plt.title("DBSCAN Clustering")
plt.xlabel(x)
plt.ylabel(y)
plt.show()

# %%
# Visualize the results
sns.scatterplot(
    x=x,
    y=y,
    s=s,
    hue='DBSCAN_2',
    data=df_1
)
plt.title("DBSCAN Clustering")
plt.xlabel(x)
plt.ylabel(y)
plt.show()

# %% [markdown]
# ## Redes Neurais

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# 2025-11-24 20:52:42.150568: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-24 20:52:42.235407: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-24 20:52:42.630527: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-24 20:52:42.632644: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-24 20:52:44.471955: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 53   41  18  41.101260  19.359319    24.359319            23             8
# 93    9   2   9.876045   3.050423     8.050423            23             9
# 20   37  16  36.714018  14.920509    19.920509            11             0
# 177  15   5  13.314530   2.728269     7.728269            42            21
# 26   15   5  17.686336   1.206506     6.206506             9             5
#
#      class style style_2  x_noise_scaled  y_noise_new_scaled  k-means  \
# 53   False     o       +        1.573645            1.831463        0
# 93    True     +       o       -1.254069           -0.614858        1
# 20   False     o       +        1.176342            1.165645        0
# 177  False     o       o       -0.942684           -0.663181        1
# 26   False     o       o       -0.546779           -0.891444        1
#
#      DBSCAN_1  DBSCAN_2
# 53          0         0
# 93          1         1
# 20          0         0
# 177         1         1
# 26          1         1

# %%
# Sample data
data = df_1[[
    'x',
    'y',
    'x_noise',
    'y_noise',
    'y_noise_new',
    'x_noise_mean',
    'y_noise_mean',
    'x_noise_scaled',
    'y_noise_new_scaled',
]]

# Build an autoencoder
input_dim = data.shape[1]
encoding_dim = 2 # Reduced dimension for clustering
input_dim
# Out:
# 9

# %%
input_layer = keras.layers.Input(shape=(input_dim,))
encoder = keras.layers.Dense(encoding_dim, activation='relu')(input_layer)
decoder = keras.layers.Dense(input_dim, activation='sigmoid')(encoder)

autoencoder = keras.Model(inputs=input_layer, outputs=decoder)
encoder_model = keras.Model(inputs=input_layer, outputs=encoder)

autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 9)]               0
#
#  dense_2 (Dense)             (None, 2)                 20
#
#  dense_3 (Dense)             (None, 9)                 27
#
# =================================================================
# Total params: 47
# Trainable params: 47
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.fit(data, data, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 0s 2ms/step - loss: 277.3236
# Epoch 2/50
# 4/4 [==============================] - 0s 3ms/step - loss: 277.2669
# Epoch 3/50
# 4/4 [==============================] - 0s 3ms/step - loss: 277.2107
# Epoch 4/50
# 4/4 [==============================] - 0s 3ms/step - loss: 277.1569
# Epoch 5/50
# 4/4 [==============================] - 0s 3ms/step - loss: 277.1022
# Epoch 6/50
# 4/4 [==============================] - 0s 5ms/step - loss: 277.0515
# Epoch 7/50
# 4/4 [==============================] - 0s 3ms/step - loss: 276.9970
# Epoch 8/50
# 4/4 [==============================] - 0s 4ms/step - loss: 276.9436
# Epoch 9/50
# 4/4 [==============================] - 0s 3ms/step - loss: 276.8883
# Epoch 10/50
# 4/4 [==============================] - 0s 4ms/step - loss: 276.8344
# Epoch 11/50
# 4/4 [==============================] - 0s 4ms/step - loss: 276.7738
# Epoch 12/50
# 4/4 [==============================] - 0s 3ms/step - loss: 276.7139
# Epoch 13/50
# 4/4 [==============================] - 0s 3ms/step - loss: 276.6519
# Epoch 14/50
# 4/4 [==============================] - 0s 3ms/step - loss: 276.5797
# Epoch 15/50
# 4/4 [==============================] - 0s 4ms/step - loss: 276.5038
# Epoch 16/50
# 4/4 [==============================] - 0s 3ms/step - loss: 276.4254
# Epoch 17/50
# 4/4 [==============================] - 0s 3ms/step - loss: 276.3364
# Epoch 18/50
# 4/4 [==============================] - 0s 2ms/step - loss: 276.2295
# Epoch 19/50
# 4/4 [==============================] - 0s 6ms/step - loss: 276.1069
# Epoch 20/50
# 4/4 [==============================] - 0s 3ms/step - loss: 275.9879
# Epoch 21/50
# 4/4 [==============================] - 0s 3ms/step - loss: 275.8714
# Epoch 22/50
# 4/4 [==============================] - 0s 3ms/step - loss: 275.7712
# Epoch 23/50
# 4/4 [==============================] - 0s 3ms/step - loss: 275.6783
# Epoch 24/50
# 4/4 [==============================] - 0s 2ms/step - loss: 275.5952
# Epoch 25/50
# 4/4 [==============================] - 0s 2ms/step - loss: 275.5126
# Epoch 26/50
# 4/4 [==============================] - 0s 2ms/step - loss: 275.4313
# Epoch 27/50
# 4/4 [==============================] - 0s 3ms/step - loss: 275.3439
# Epoch 28/50
# 4/4 [==============================] - 0s 2ms/step - loss: 275.2500
# Epoch 29/50
# 4/4 [==============================] - 0s 3ms/step - loss: 275.1524
# Epoch 30/50
# 4/4 [==============================] - 0s 2ms/step - loss: 275.0390
# Epoch 31/50
# 4/4 [==============================] - 0s 2ms/step - loss: 274.9040
# Epoch 32/50
# 4/4 [==============================] - 0s 2ms/step - loss: 274.6890
# Epoch 33/50
# 4/4 [==============================] - 0s 3ms/step - loss: 274.3866
# Epoch 34/50
# 4/4 [==============================] - 0s 3ms/step - loss: 274.0688
# Epoch 35/50
# 4/4 [==============================] - 0s 2ms/step - loss: 273.8208
# Epoch 36/50
# 4/4 [==============================] - 0s 3ms/step - loss: 273.6373
# Epoch 37/50
# 4/4 [==============================] - 0s 3ms/step - loss: 273.5046
# Epoch 38/50
# 4/4 [==============================] - 0s 3ms/step - loss: 273.3764
# Epoch 39/50
# 4/4 [==============================] - 0s 3ms/step - loss: 273.2617
# Epoch 40/50
# 4/4 [==============================] - 0s 3ms/step - loss: 273.1740
# Epoch 41/50
# 4/4 [==============================] - 0s 3ms/step - loss: 273.1089
# Epoch 42/50
# 4/4 [==============================] - 0s 2ms/step - loss: 273.0576
# Epoch 43/50
# 4/4 [==============================] - 0s 3ms/step - loss: 273.0180
# Epoch 44/50
# 4/4 [==============================] - 0s 2ms/step - loss: 272.9865
# Epoch 45/50
# 4/4 [==============================] - 0s 2ms/step - loss: 272.9598
# Epoch 46/50
# 4/4 [==============================] - 0s 3ms/step - loss: 272.9368
# Epoch 47/50
# 4/4 [==============================] - 0s 2ms/step - loss: 272.9177
# Epoch 48/50
# 4/4 [==============================] - 0s 3ms/step - loss: 272.9006
# Epoch 49/50
# 4/4 [==============================] - 0s 2ms/step - loss: 272.8873
# Epoch 50/50
# 4/4 [==============================] - 0s 2ms/step - loss: 272.8749

# %%
# Get the encoded representation
encoded_data = encoder_model.predict(data)
encoded_data[:3]
# Out:
# 4/4 [==============================] - 0s 2ms/step
# array([[31.668505, 17.489157],
#        [20.416546, 14.825215],
#        [19.574648,  9.063927]], dtype=float32)

# %%
# Apply K-Means clustering to the encoded data
kmeans = KMeans(n_clusters=2, random_state=0, n_init=10)
clusters = kmeans.fit_predict(encoded_data)
df_1['NN-k-means'] = clusters
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 53   41  18  41.101260  19.359319    24.359319            23             8
# 93    9   2   9.876045   3.050423     8.050423            23             9
# 20   37  16  36.714018  14.920509    19.920509            11             0
# 177  15   5  13.314530   2.728269     7.728269            42            21
# 26   15   5  17.686336   1.206506     6.206506             9             5
#
#      class style style_2  x_noise_scaled  y_noise_new_scaled  k-means  \
# 53   False     o       +        1.573645            1.831463        0
# 93    True     +       o       -1.254069           -0.614858        1
# 20   False     o       +        1.176342            1.165645        0
# 177  False     o       o       -0.942684           -0.663181        1
# 26   False     o       o       -0.546779           -0.891444        1
#
#      DBSCAN_1  DBSCAN_2  NN-k-means
# 53          0         0           1
# 93          1         1           0
# 20          0         0           0
# 177         1         1           1
# 26          1         1           0

# %%
# Visualize the results
sns.scatterplot(
    x=x,
    y=y,
    s=s,
    hue='NN-k-means',
    data=df_1
)
plt.title("Redes Neurais + K-Means Clustering")
plt.xlabel(x)
plt.ylabel(y)
plt.show()

# %%
# dump(df_1, './data/05_aula_df_3')
# Out:
# ['./data/05_aula_df_3']

# %%
df_1 = load('./data/05_aula_df_3')
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 53   41  18  41.101260  19.359319    24.359319            23             8
# 93    9   2   9.876045   3.050423     8.050423            23             9
# 20   37  16  36.714018  14.920509    19.920509            11             0
# 177  15   5  13.314530   2.728269     7.728269            42            21
# 26   15   5  17.686336   1.206506     6.206506             9             5
#
#      class style style_2  x_noise_scaled  y_noise_new_scaled  k-means  \
# 53   False     o       +        1.573645            1.831463        0
# 93    True     +       o       -1.254069           -0.614858        1
# 20   False     o       +        1.176342            1.165645        0
# 177  False     o       o       -0.942684           -0.663181        1
# 26   False     o       o       -0.546779           -0.891444        1
#
#      DBSCAN_1  DBSCAN_2  NN-k-means
# 53          0         0           1
# 93          1         1           0
# 20          0         0           0
# 177         1         1           1
# 26          1         1           0

# %%
x_cluster = 'k-means'
fig, ax = plt.subplots(1, 2, figsize=(13, 5))
plt.suptitle('Diferença das classes clusterizadas')
g = sns.boxplot(
    x=x_cluster,
    y=x,
    data=df_1,
    ax=ax[0]
)
g.set(
    title = 'X para '+x_cluster,
    xlabel = x_cluster,
    ylabel = 'X',
)
g = sns.boxplot(
    x=x_cluster,
    y=y,
    data=df_1,
    ax=ax[1]
)
g.set(
    title = 'Y para '+x_cluster,
    xlabel = x_cluster,
    ylabel = 'Y',
)
plt.show()

# %%
x_cluster = 'DBSCAN_1'
fig, ax = plt.subplots(1, 2, figsize=(13, 5))
plt.suptitle('Diferença das classes clusterizadas')
g = sns.boxplot(
    x=x_cluster,
    y=x,
    data=df_1,
    ax=ax[0]
)
g.set(
    title = 'X para '+x_cluster,
    xlabel = x_cluster,
    ylabel = 'X',
)
g = sns.boxplot(
    x=x_cluster,
    y=y,
    data=df_1,
    ax=ax[1]
)
g.set(
    title = 'Y para '+x_cluster,
    xlabel = x_cluster,
    ylabel = 'Y',
)
plt.show()

# %%
x_cluster = 'DBSCAN_2'
fig, ax = plt.subplots(1, 2, figsize=(13, 5))
plt.suptitle('Diferença das classes clusterizadas')
g = sns.boxplot(
    x=x_cluster,
    y=x,
    data=df_1,
    ax=ax[0]
)
g.set(
    title = 'X para '+x_cluster,
    xlabel = x_cluster,
    ylabel = 'X',
)
g = sns.boxplot(
    x=x_cluster,
    y=y,
    data=df_1,
    ax=ax[1]
)
g.set(
    title = 'Y para '+x_cluster,
    xlabel = x_cluster,
    ylabel = 'Y',
)
plt.show()

# %%
x_cluster = 'NN-k-means'
fig, ax = plt.subplots(1, 2, figsize=(13, 5))
plt.suptitle('Diferença das classes clusterizadas')
g = sns.boxplot(
    x=x_cluster,
    y=x,
    data=df_1,
    ax=ax[0]
)
g.set(
    title = 'X para '+x_cluster,
    xlabel = x_cluster,
    ylabel = 'X',
)
g = sns.boxplot(
    x=x_cluster,
    y=y,
    data=df_1,
    ax=ax[1]
)
g.set(
    title = 'Y para '+x_cluster,
    xlabel = x_cluster,
    ylabel = 'Y',
)
plt.show()

# %%
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 53   41  18  41.101260  19.359319    24.359319            23             8
# 93    9   2   9.876045   3.050423     8.050423            23             9
# 20   37  16  36.714018  14.920509    19.920509            11             0
# 177  15   5  13.314530   2.728269     7.728269            42            21
# 26   15   5  17.686336   1.206506     6.206506             9             5
#
#      class style style_2  x_noise_scaled  y_noise_new_scaled  k-means  \
# 53   False     o       +        1.573645            1.831463        0
# 93    True     +       o       -1.254069           -0.614858        1
# 20   False     o       +        1.176342            1.165645        0
# 177  False     o       o       -0.942684           -0.663181        1
# 26   False     o       o       -0.546779           -0.891444        1
#
#      DBSCAN_1  DBSCAN_2  NN-k-means
# 53          0         0           1
# 93          1         1           0
# 20          0         0           0
# 177         1         1           1
# 26          1         1           0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from joblib import dump, load
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

from src.functions import Functions

# %%
def func_dados(valor) -> float:
    valor_final = 5 + valor*2
    return valor_final

# %%
n = 200
b = np.random.randint(1, 20, n)
b[:10]
# Out:
# array([ 7, 17, 13,  1, 13,  5, 17,  5,  5, 11], dtype=int32)

# %%
a = np.apply_along_axis(func_dados, 0, b)
a[:10]
# Out:
# array([19, 39, 31,  7, 31, 15, 39, 15, 15, 27], dtype=int32)

# %%
df = pd.DataFrame(
    data={
        'x': a,
        'y': b
    }
).round(0)
df.head()
# Out:
#     x   y
# 0  19   7
# 1  39  17
# 2  31  13
# 3   7   1
# 4  31  13

# %%
def func_dados_erro(valor: int) -> float:
    erro = np.random.normal(0, 2, 1)
    valor_final = valor + erro[0]
    return valor_final

# %%
df['x_noise'] = df['x'].apply(func=func_dados_erro)
df['y_noise'] = df['y'].apply(func=func_dados_erro)
df.head()
# Out:
#     x   y    x_noise    y_noise
# 0  19   7  18.573527   5.659021
# 1  39  17  39.715577  17.285663
# 2  31  13  27.642549  11.613137
# 3   7   1   9.928362  -0.390565
# 4  31  13  32.723736  13.052903

# %%
def novo_valor(valor: int, correct: float, q1y: float, q3y: float) -> float:
    if valor <= q1y:
        return valor + correct
    if valor >= q3y:
        return valor + correct
    return valor

# %%
q1y = df.y_noise.quantile(.25)
q3y = df.y_noise.quantile(.75)

df['y_noise_new'] = df['y_noise'].apply(func=novo_valor, args=(5, q1y, q3y))
df.head()
# Out:
#     x   y    x_noise    y_noise  y_noise_new
# 0  19   7  18.573527   5.659021     5.659021
# 1  39  17  39.715577  17.285663    22.285663
# 2  31  13  27.642549  11.613137    11.613137
# 3   7   1   9.928362  -0.390565     4.609435
# 4  31  13  32.723736  13.052903    13.052903

# %%
minx = df.x_noise.min()
q1x = df.x_noise.quantile(.25)
q3x = df.x_noise.quantile(.75)
maxx = df.x_noise.max()

miny = df.y_noise_new.min()
q1y = df.y_noise_new.quantile(.25)
q3y = df.y_noise_new.quantile(.75)
maxy = df.y_noise_new.max()

noise = pd.DataFrame({
    'x':[minx, q1x, q3x, maxx],
    'y':[miny, q1y, q3y, maxy],
})
noise
# Out:
#            x          y
# 0   3.597901   1.841378
# 1  15.704526   7.465874
# 2  33.341388  15.718027
# 3  46.084285  27.269337

# %%
lista_valores = list()

[lista_valores.append(x) for x in np.random.randint(minx, q1x, 50)]
[lista_valores.append(x) for x in np.random.randint(q1x, q3x, 100)]
[lista_valores.append(x) for x in np.random.randint(q3x, maxx, 50)]

df["x_noise_mean"] = np.array(lista_valores)

lista_valores = list()

[lista_valores.append(y) for y in np.random.randint(miny, q1y, 50)]
[lista_valores.append(y) for y in np.random.randint(q1y, q3y, 100)]
[lista_valores.append(y) for y in np.random.randint(q3y, maxy, 50)]

df["y_noise_mean"] = np.array(lista_valores)

df.head()
# Out:
#     x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean
# 0  19   7  18.573527   5.659021     5.659021            12             5
# 1  39  17  39.715577  17.285663    22.285663            14             3
# 2  31  13  27.642549  11.613137    11.613137             4             4
# 3   7   1   9.928362  -0.390565     4.609435             3             4
# 4  31  13  32.723736  13.052903    13.052903            11             4

# %%
df_1 = df.sample(frac=.5)
df_2 = df.sample(frac=.5)

# %%
df_1['class'] = True
df_1.loc[df_1['x_noise'].sample(frac=.75).index, 'class'] = False
df_1['class'].value_counts()
# Out:
# class
# False    75
# True     25
# Name: count, dtype: int64

# %%
df_1['style'] = "o"
df_1.loc[df_1[df_1['class']].index, 'style'] = '+'
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 30   27  11  23.932672  10.355406    10.355406             9             2
# 4    31  13  32.723736  13.052903    13.052903            11             4
# 135  43  19  46.084285  22.269337    27.269337            28            14
# 142  21   8  18.894138   9.236923     9.236923            24             7
# 87   19   7  16.798585   9.707204     9.707204            22            13
#
#      class style
# 30    True     +
# 4    False     o
# 135  False     o
# 142  False     o
# 87   False     o

# %%
df_1['style'].value_counts()
# Out:
# style
# o    75
# +    25
# Name: count, dtype: int64

# %%
df_1['style_2'] = "o"
df_1.loc[df_1[df_1['y_noise_new'] > 17].index, 'style_2'] = '+'
df_1.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 30   27  11  23.932672  10.355406    10.355406             9             2
# 4    31  13  32.723736  13.052903    13.052903            11             4
# 135  43  19  46.084285  22.269337    27.269337            28            14
# 142  21   8  18.894138   9.236923     9.236923            24             7
# 87   19   7  16.798585   9.707204     9.707204            22            13
#
#      class style style_2
# 30    True     +       o
# 4    False     o       o
# 135  False     o       +
# 142  False     o       o
# 87   False     o       o

# %%
# dump(df_1, 'df_1')
# dump(df_2, 'df_2')
# dump(df, 'df')

# %%
df = load('./data/df')
df_1 = load('./data/df_1')
df_2 = load('./data/df_2')

# %%
obsr = "Variável 1"
pred = "Variável 2"
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    data=df_1
)
sns.lineplot(
    x='x',
    y='y',
    data=df_1,
    c='r',
)
sns.lineplot(
    x='x_noise_mean',
    y='y_noise_mean',
    data=df_1,
    c='g',
)
sns.lineplot(
    x='x_noise',
    y='y_noise_new',
    data=df_1,
    c='y',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.show()

# %%
print(f"RMSE red: {mean_squared_error(df['x'], df['y'])}")
print(f"RMSE gree: {mean_squared_error(df['x_noise_mean'], df['y_noise_mean'])}")
print(f"RMSE yellow: {mean_squared_error(df['x_noise'], df['x_noise'])}")
# Out:
# RMSE red: 251.58
# RMSE gree: 212.315
# RMSE yellow: 0.0

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    data=df_1
)
sns.lineplot(
    x='x',
    y='y',
    data=df_2,
    c='r',
)
sns.lineplot(
    x='x_noise',
    y='y_noise_new',
    data=df_2,
    c='y',
)
sns.lineplot(
    x='x_noise_mean',
    y='y_noise_mean',
    data=df_2,
    c='g',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.show()

# %%
print(f"RMSE red: {mean_squared_error(df_1['x'], df_2['y'])}")
print(f"RMSE gree: {mean_squared_error(df_1['x_noise_mean'], df_2['y_noise_mean'])}")
print(f"RMSE yellow: {mean_squared_error(df_1['x_noise'], df_2['x_noise'])}")
# Out:
# RMSE red: 443.96
# RMSE gree: 342.57
# RMSE yellow: 303.4703264135716

# %% [markdown]
# ---

# %%
palette = {False:'blue', True:'magenta'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='class',
    style='style',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
palette = {'o':'black', '+':'black'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
palette = {'o':'blue', '+':'magenta'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [0, 50], # x
    [10, 19], # y
    c='orange',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [30, 30], # x
    [0, 30], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [30, 30], # x
    [0, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    [30, 30], # x
    [18, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    28, 17, '*g', markersize=25
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    28, 17, '*', c=palette['+'], markersize=25
)
plt.plot(
    [0, 50], # x
    [10, 19], # y
    c='orange',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    style='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=df_1
)
plt.plot(
    28, 17, '*', c=palette['o'], markersize=25
)
plt.plot(
    [30, 30], # x
    [18, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %% [markdown]
# ---

# %%
n = 50
x = np.random.randint(5, 45, n)
y = np.random.randint(5, 30, n)
df_nova = pd.DataFrame({'x':x,'y':y})
df_nova.head()
# Out:
#     x   y
# 0  39  21
# 1  10  15
# 2  33  21
# 3  43  15
# 4  18   6

# %%
palette = {'x':'blue', 'y':'magenta'}
df_nova['class'] = palette['x']
df_nova.loc[df_nova[df_nova['y'] >= 15].index, 'class'] = palette['y']
df_nova.head()
# Out:
#     x   y    class
# 0  39  21  magenta
# 1  10  15  magenta
# 2  33  21  magenta
# 3  43  15  magenta
# 4  18   6     blue

# %%
# dump(df_nova, 'df_nova')
df_nova = load('./data/df_nova')

# %%
palette = {'magenta': 'blue', 'blue': 'magenta'}
sns.scatterplot(
    x='x',
    y='y',
    hue='class',
    # style='class',
    palette=palette,
    legend=False,
    s=100,
    data=df_nova
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x',
    y='y',
    hue='class',
    # style='class',
    palette=palette,
    legend=False,
    s=100,
    data=df_nova
)
plt.plot(
    [30, 30], # x
    [18, 30], # y
    c='r',
    linewidth=4
)
plt.plot(
    [30, 50], # x
    [18, 18], # y
    c='r',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
sns.scatterplot(
    x='x',
    y='y',
    hue='class',
    # style='class',
    palette=palette,
    legend=False,
    s=100,
    data=df_nova
)
plt.plot(
    [0, 50], # x
    [10, 19], # y
    c='orange',
    linewidth=4
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %% [markdown]
# ---

# %%
x = np.random.randint(543, 592, n)
x
# Out:
# array([545, 554, 554, 588, 548, 570, 578, 557, 587, 569, 546, 586, 544,
#        574, 584, 561, 578, 572, 582, 576, 557, 568, 588, 574, 562, 587,
#        569, 568, 581, 556, 573, 580, 557, 552, 563, 567, 565, 587, 585,
#        543, 570, 563, 561, 543, 579, 582, 569, 576, 550, 552], dtype=int32)

# %%
np.mean(x)
# Out:
# np.float64(567.6)

# %%
np.median(x)
# Out:
# np.float64(569.0)

# %%
np.std(x)
# Out:
# np.float64(13.557285864065861)

# %% [markdown]
# ---

# %%
from src.functions import Functions

# %%
dados = df_1.sample(50).copy()
# dump(dados, "./data/dados")
dados = load("./data/dados")
dados.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 157  41  18  39.258567  14.165749    14.165749            37            15
# 129  35  15  34.046405  13.371884    13.371884            32            10
# 152  13   4  10.290340   2.203792     7.203792            36            15
# 140  21   8  21.131655   5.785083     5.785083            24            14
# 126  29  12  28.378891  12.513669    12.513669            17            10
#
#      class style style_2
# 157   True     +       o
# 129  False     o       o
# 152  False     o       o
# 140   True     +       o
# 126   True     +       o

# %%
palette = {'o':'black', '+':'black'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([0,30])
plt.show()

# %%
curva = Functions(
    dados=dados.loc[:, ['x_noise', 'y_noise_new']],
    coluna_x='x_noise',
    coluna_y='y_noise_new',
)
curva.equacao_da_reta_calculo()
# Out:
# np.float64(24.977786651980264)

# %%
dados.loc[:, ['x_noise', 'y_noise_new']].max()
# Out:
# x_noise        45.192719
# y_noise_new    24.977787
# dtype: float64

# %%
dados.loc[:, ['x_noise', 'y_noise_new']].min()
# Out:
# x_noise        4.720592
# y_noise_new    4.192424
# dtype: float64

# %%
curva.equacao_da_reta_calculo(new_y=dados.loc[:, ['x_noise', 'y_noise_new']].max()[0])
# Out:
# C:\Users\gfsil\AppData\Local\Temp\ipykernel_26448\3016762172.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   curva.equacao_da_reta_calculo(new_y=dados.loc[:, ['x_noise', 'y_noise_new']].max()[0])
# np.float64(24.977786651980264)

# %%
curva.equacao_da_reta_calculo(new_y=dados.loc[:, ['x_noise', 'y_noise_new']].min()[0])
# Out:
# C:\Users\gfsil\AppData\Local\Temp\ipykernel_26448\3146250567.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   curva.equacao_da_reta_calculo(new_y=dados.loc[:, ['x_noise', 'y_noise_new']].min()[0])
# np.float64(4.192424205301381)

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.equacao_da_reta_calculo, args=[12,])
normalizador = 37
dados['y_noise_new_cal'] = dados['y_noise_new']*normalizador
# dados['y_noise_calculo'] = dados['x_noise'].apply(curva.equacao_da_reta_calculo)
dados.head()
# Out:
#       x   y    x_noise    y_noise  y_noise_new  x_noise_mean  y_noise_mean  \
# 157  41  18  39.258567  14.165749    14.165749            37            15
# 129  35  15  34.046405  13.371884    13.371884            32            10
# 152  13   4  10.290340   2.203792     7.203792            36            15
# 140  21   8  21.131655   5.785083     5.785083            24            14
# 126  29  12  28.378891  12.513669    12.513669            17            10
#
#      class style style_2  y_noise_calculo  y_noise_new_cal
# 157   True     +       o        32.125460       524.132699
# 129  False     o       o        28.913274       494.759692
# 152  False     o       o        14.272727       266.540291
# 140   True     +       o        20.954085       214.048081
# 126   True     +       o        25.420460       463.005763

# %%
obsr = 'Gramas'
pred = 'Calorias'
palette = {'o':'black', '+':'black'}
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [600, 0,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
rmse = mean_squared_error(dados['y_noise_calculo'],dados['y_noise_new_cal'])
plt.title(f"RMSE: {rmse:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
obsr = "Observado"
pred = "Predito"

dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
sst =np.sum((dados['y_noise_new_cal'] - dados['y_noise_calculo'])**2)
plt.title(f"SQT: {sst:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
dados_reta = [50, 16,]
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
obsr = "Observado"
pred = "Predito"

dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)
for n in range(10):
    index = dados['x_noise'].sample(1).index[0]
    x = dados['x_noise'][index]
    y = dados['y_noise_calculo'][index]
    d = dados['y_noise_new_cal'][index] - y

    plt.arrow(
        x,
        y,
        0,
        d,
        head_width=1,
        head_length=50,
        length_includes_head=True,
        color='g',
    )
ssr =np.sum((dados['y_noise_new_cal'] - dados['y_noise_calculo'])**2)
plt.title(f"SQR: {ssr:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %%
r2 = 1-(ssr/sst)
r2
# Out:
# np.float64(0.8271168764754365)

# %%
tam = len(dados['y_noise_new_cal'])
r2a = 1 - (tam/(tam-1))*(1-r2)
r2a
# Out:
# np.float64(0.8235886494647311)

# %%
y_obs = dados['y_noise_new_cal']
y_pred = dados['y_noise_calculo']
r2_score(y_obs, y_pred)
# Out:
# 0.767865605917734

# %%
mae = np.sum(((y_obs - y_pred)**2)**0.5)/tam
mae
# Out:
# np.float64(88.11127377856533)

# %%
mean_absolute_error(y_obs, y_pred)
# Out:
# 88.11127377856533

# %%
mse = np.sum((y_obs - y_pred)**2)/tam
mse
# Out:
# np.float64(11271.029590909518)

# %%
mean_squared_error(y_obs, y_pred)
# Out:
# 11271.029590909518

# %%
rmae = mae**0.5
rmae
# Out:
# np.float64(9.38676055828449)

# %%
root_mean_squared_error(y_obs, y_pred)
# Out:
# 106.16510533555514

# %%
mape = np.sum((((y_obs - y_pred)**2)**0.5)/y_obs)/tam
mape
# Out:
# np.float64(0.2104011557423452)

# %%
mean_absolute_percentage_error(y_obs, y_pred)
# Out:
# 0.2104011557423452

# %%
dados['y_noise_calculo'] = dados['x_noise'].apply(curva.reta, args=dados_reta)
sns.scatterplot(
    x='x_noise',
    y='y_noise_new_cal',
    hue='style_2',
    legend=False,
    s=100,
    palette=palette,
    data=dados
)
sns.lineplot(
    x='x_noise',
    y='y_noise_calculo',
    data=dados,
    c='r',
)    
plt.plot(
    18, 566, '*', c='g', markersize=25
)
plt.arrow(
    18,
    340,
    0,
    196,
    head_width=1,
    head_length=50,
    length_includes_head=True,
    color='g',
)
rmse = mean_squared_error(dados['y_noise_calculo'],dados['y_noise_new_cal'])
plt.title(f"RMSE: {rmse:,.2f}")
plt.xlabel(obsr)
plt.ylabel(pred)
plt.xlim([0,50])
plt.ylim([normalizador,30*normalizador])
plt.show()

# %% [markdown]
# ---

# %%
data = [
[2025,16537],
[2024,5434],
[2023,38871],
[2022,39224],
[2021,31559],
[2020,2278],
[2019,16472],
[2018,11267],
[2017,8257],
[2016,6832],
[2015,6803],
[2014,6908],
[2013,6832],
[2012,5574],
[2011,5314],
[2010,4491],
[2009,4642],
[2008,4906],
[2007,4467],
[2006,4065],
[2005,3639],
[2004,2762],
[2003,1802],
[2002,1462],
[2001,1343],
[2000,1248],
[1999,106],
[1998,1025],
[1997,982],
[1996,862],
[1995,905],
[1994,729],
[1993,61],
[1992,438],
[1991,456],
[1990,372],
[1989,295],
[1988,219],
[1987,198],
[1986,165],
[1985,65],
[1984,3],
[1983,23],
[1982,13],
[1981,11],
[1980,12],
[1979,4],
[1978,3],
[1977,5],
[1976,7],
[1975,5],
[1974,7],
[1973,6],
[1972,5],
[1971,3],
[1970,2],
[1969,1],
[1968,5],
[1967,3],
[1966,2],
[1965,4],
[1964,5],
[1963,5],
[1962,6],
[1961,3],
[1960,1],
[1958,1],
[1956,1],
[1954,1],
[1953,1],
[1952,1],
[1951,1],
]
dados_pubmed = pd.DataFrame(data)
dados_pubmed.rename(columns={0: 'Year', 1: 'Works'}, inplace=True)
dados_pubmed.head()
# Out:
#    Year  Works
# 0  2025  16537
# 1  2024   5434
# 2  2023  38871
# 3  2022  39224
# 4  2021  31559

# %%
plt.figure(figsize=(20,5))
plt.title('Número de Públicações com IA no Pubmed')
sns.barplot(
    x='Year',
    y='Works',
    legend=False,
    color='green',
    data=dados_pubmed
)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Colab
#
# ![Colab](./img/colab.png)

# %% [markdown]
# https://1drv.ms/v/c/808ebfd9a0d86213/IQCvd0JdCvYGRbvnz5dAT3RLAQ8zyCkIW9ojajG9rfNaJFA?e=CQOj8F

# %% [markdown]
# Ambiente destinado para alunos que (4) vieram só para comer ou (3) não faço ideia se vou usar ou não:
#
# - Nível baixo de controle de verções;
# - Sem instalações locais;
# - Sem necessidade de configuração local;
# - Baixa rastreabilidade e reprodutibilidade;
#
# MUITO FÁCIL

# %% [markdown]
# # Python Local
#
# ![Local](./img/python.jpg)

# %% [markdown]
# https://1drv.ms/v/c/808ebfd9a0d86213/IQDFDhPA15amSoIhhYDNs0VVAZl9BbCNB0KfHBPGAdUjBrY?e=YFKfcN
#
# complemento:<br>
# https://1drv.ms/v/c/808ebfd9a0d86213/IQBIk_4Pv_E8R4GmujCR85bFAXNCVP79yvigY5m43ru7Vls?e=Dg6fYO

# %% [markdown]
# Ambiente destinado para alunos que (2) talvez use, mas não sei bem onde:
#
# - Nível intermediario de controle de verções;
# - Instalação local de Python;
# - Sem necessidade de configuração local;
# - Baixa rastreabilidade e reprodutibilidade;
#
# MAIS FÁCIL

# %% [markdown]
# # Docker
#
# ![Docker](./img/docker.png)

# %% [markdown]
# https://1drv.ms/v/c/808ebfd9a0d86213/IQC4-fh16pKESbQG9NCGlEl2AYI88rC9RFK4A0fU3kpoOkI?e=QyhOTI

# %% [markdown]
# Ambiente destinado para alunos que (1) com certeza vou usar:
#
# - Nível máximo de controle de verções;
# - Instalação local de Docker e Python;
# - Configurações locais via containers;
# - Máxima rastreabilidade e reprodutibilidade;
#
# MAIS DIFÍCIL
